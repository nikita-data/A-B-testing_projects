# %% [markdown]
# # Анализ поведения пользователей мобильного приложения «Ненужные вещи»

# %% [markdown]
# <h1>Содержание<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Обзор-данных" data-toc-modified-id="Обзор-данных-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Обзор данных</a></span><ul class="toc-item"><li><span><a href="#Считаем-CSV-файлы--с-данными" data-toc-modified-id="Считаем-CSV-файлы--с-данными-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Считаем CSV-файлы  с данными</a></span></li><li><span><a href="#Выведем-первые-строки-каждого-набора-данных-и-изучим-общую-информацию-по-каждому-датафрейму" data-toc-modified-id="Выведем-первые-строки-каждого-набора-данных-и-изучим-общую-информацию-по-каждому-датафрейму-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Выведем первые строки каждого набора данных и изучим общую информацию по каждому датафрейму</a></span><ul class="toc-item"><li><span><a href="#Журнал-действий-пользователей" data-toc-modified-id="Журнал-действий-пользователей-1.2.1"><span class="toc-item-num">1.2.1&nbsp;&nbsp;</span>Журнал действий пользователей</a></span></li><li><span><a href="#Данные-по-источникам-привлечения-пользователей" data-toc-modified-id="Данные-по-источникам-привлечения-пользователей-1.2.2"><span class="toc-item-num">1.2.2&nbsp;&nbsp;</span>Данные по источникам привлечения пользователей</a></span></li></ul></li></ul></li><li><span><a href="#Предобработка-данных" data-toc-modified-id="Предобработка-данных-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Предобработка данных</a></span><ul class="toc-item"><li><span><a href="#Стиль-заголовков" data-toc-modified-id="Стиль-заголовков-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Стиль заголовков</a></span></li><li><span><a href="#Объединение-данных-в-один-датафрейм" data-toc-modified-id="Объединение-данных-в-один-датафрейм-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Объединение данных в один датафрейм</a></span></li><li><span><a href="#Обработка-пропусков" data-toc-modified-id="Обработка-пропусков-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Обработка пропусков</a></span></li><li><span><a href="#Обработка-явных--дубликатов" data-toc-modified-id="Обработка-явных--дубликатов-2.4"><span class="toc-item-num">2.4&nbsp;&nbsp;</span>Обработка явных  дубликатов</a></span></li><li><span><a href="#Изменение-типов-данных" data-toc-modified-id="Изменение-типов-данных-2.5"><span class="toc-item-num">2.5&nbsp;&nbsp;</span>Изменение типов данных</a></span></li><li><span><a href="#Обработка-аномальных-значений" data-toc-modified-id="Обработка-аномальных-значений-2.6"><span class="toc-item-num">2.6&nbsp;&nbsp;</span>Обработка аномальных значений</a></span></li><li><span><a href="#Обработка-неявных--дубликатов" data-toc-modified-id="Обработка-неявных--дубликатов-2.7"><span class="toc-item-num">2.7&nbsp;&nbsp;</span>Обработка неявных  дубликатов</a></span></li><li><span><a href="#Добавление-столбцов" data-toc-modified-id="Добавление-столбцов-2.8"><span class="toc-item-num">2.8&nbsp;&nbsp;</span>Добавление столбцов</a></span><ul class="toc-item"><li><span><a href="#Добавление-столбца-session_id" data-toc-modified-id="Добавление-столбца-session_id-2.8.1"><span class="toc-item-num">2.8.1&nbsp;&nbsp;</span>Добавление столбца session_id</a></span></li><li><span><a href="#Добавление-столбца-event_date" data-toc-modified-id="Добавление-столбца-event_date-2.8.2"><span class="toc-item-num">2.8.2&nbsp;&nbsp;</span>Добавление столбца event_date</a></span></li><li><span><a href="#Добавление-столбца-с-номером-недели" data-toc-modified-id="Добавление-столбца-с-номером-недели-2.8.3"><span class="toc-item-num">2.8.3&nbsp;&nbsp;</span>Добавление столбца с номером недели</a></span></li></ul></li><li><span><a href="#Изменение-порядка-расположения-столбцов" data-toc-modified-id="Изменение-порядка-расположения-столбцов-2.9"><span class="toc-item-num">2.9&nbsp;&nbsp;</span>Изменение порядка расположения столбцов</a></span></li></ul></li><li><span><a href="#Исследовательский-анализ-данных" data-toc-modified-id="Исследовательский-анализ-данных-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Исследовательский анализ данных</a></span><ul class="toc-item"><li><span><a href="#Профили-пользователей" data-toc-modified-id="Профили-пользователей-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Профили пользователей</a></span></li><li><span><a href="#Количество-действий-и-сессий-в-логе" data-toc-modified-id="Количество-действий-и-сессий-в-логе-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Количество действий и сессий в логе</a></span></li><li><span><a href="#Количество-уникальных-пользователей-в-логе" data-toc-modified-id="Количество-уникальных-пользователей-в-логе-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Количество уникальных пользователей в логе</a></span></li><li><span><a href="#Количество-действий--на-пользователя" data-toc-modified-id="Количество-действий--на-пользователя-3.4"><span class="toc-item-num">3.4&nbsp;&nbsp;</span>Количество действий  на пользователя</a></span></li><li><span><a href="#Количество-сессий-на-пользователя" data-toc-modified-id="Количество-сессий-на-пользователя-3.5"><span class="toc-item-num">3.5&nbsp;&nbsp;</span>Количество сессий на пользователя</a></span></li><li><span><a href="#Длительность-сессии-пользователя" data-toc-modified-id="Длительность-сессии-пользователя-3.6"><span class="toc-item-num">3.6&nbsp;&nbsp;</span>Длительность сессии пользователя</a></span></li><li><span><a href="#Оценка-пользовательской-активности-DAU,WAU" data-toc-modified-id="Оценка-пользовательской-активности-DAU,WAU-3.7"><span class="toc-item-num">3.7&nbsp;&nbsp;</span>Оценка пользовательской активности DAU,WAU</a></span></li><li><span><a href="#Распределение-привлеченных-пользователей-по-источникам" data-toc-modified-id="Распределение-привлеченных-пользователей-по-источникам-3.8"><span class="toc-item-num">3.8&nbsp;&nbsp;</span>Распределение привлеченных пользователей по источникам</a></span></li><li><span><a href="#Доли-совершённых-действий-по-пользователям" data-toc-modified-id="Доли-совершённых-действий-по-пользователям-3.9"><span class="toc-item-num">3.9&nbsp;&nbsp;</span>Доли совершённых действий по пользователям</a></span></li><li><span><a href="#Доля-сессий-с-целевым-действием" data-toc-modified-id="Доля-сессий-с-целевым-действием-3.10"><span class="toc-item-num">3.10&nbsp;&nbsp;</span>Доля сессий с целевым действием</a></span></li></ul></li><li><span><a href="#Анализ-влияния-действий-на-совершение-целевого-события" data-toc-modified-id="Анализ-влияния-действий-на-совершение-целевого-события-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Анализ влияния действий на совершение целевого события</a></span><ul class="toc-item"><li><span><a href="#Топ-4-сценария-просмотра-контактов-пользователя" data-toc-modified-id="Топ-4-сценария-просмотра-контактов-пользователя-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Топ 4 сценария просмотра контактов пользователя</a></span></li><li><span><a href="#Воронки-действий-пользователей--по-топ-4-сценариям" data-toc-modified-id="Воронки-действий-пользователей--по-топ-4-сценариям-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Воронки действий пользователей  по топ 4 сценариям</a></span><ul class="toc-item"><li><span><a href="#Топ-1-сценарий-(tips_show-->-contacts_show)" data-toc-modified-id="Топ-1-сценарий-(tips_show-->-contacts_show)-4.2.1"><span class="toc-item-num">4.2.1&nbsp;&nbsp;</span>Топ 1 сценарий (tips_show -&gt; contacts_show)</a></span></li><li><span><a href="#Топ-2-сценарий-(contacts_show)" data-toc-modified-id="Топ-2-сценарий-(contacts_show)-4.2.2"><span class="toc-item-num">4.2.2&nbsp;&nbsp;</span>Топ 2 сценарий (contacts_show)</a></span></li><li><span><a href="#Топ-3-сценарий-(search_1-->-contacts_show)" data-toc-modified-id="Топ-3-сценарий-(search_1-->-contacts_show)-4.2.3"><span class="toc-item-num">4.2.3&nbsp;&nbsp;</span>Топ 3 сценарий (search_1 -&gt; contacts_show)</a></span></li><li><span><a href="#Топ-4-сценарий-(map-->-tips_show--->--contacts_show)" data-toc-modified-id="Топ-4-сценарий-(map-->-tips_show--->--contacts_show)-4.2.4"><span class="toc-item-num">4.2.4&nbsp;&nbsp;</span>Топ 4 сценарий (map -&gt; tips_show  -&gt;  contacts_show)</a></span></li></ul></li></ul></li><li><span><a href="#Оценка-частоты-действий-пользователей-просмотревших-контакты" data-toc-modified-id="Оценка-частоты-действий-пользователей-просмотревших-контакты-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Оценка частоты действий пользователей просмотревших контакты</a></span><ul class="toc-item"><li><span><a href="#Расчёт-относительной-частоты-событий-группы-пользователей,-которые-смотрели-контакты-contacts_show" data-toc-modified-id="Расчёт-относительной-частоты-событий-группы-пользователей,-которые-смотрели-контакты-contacts_show-5.1"><span class="toc-item-num">5.1&nbsp;&nbsp;</span>Расчёт относительной частоты событий группы пользователей, которые смотрели контакты contacts_show</a></span></li><li><span><a href="#Расчёт-относительной-частоты-событий-группы-пользователей,-которые-не-смотрели-контакты-contacts_show" data-toc-modified-id="Расчёт-относительной-частоты-событий-группы-пользователей,-которые-не-смотрели-контакты-contacts_show-5.2"><span class="toc-item-num">5.2&nbsp;&nbsp;</span>Расчёт относительной частоты событий группы пользователей, которые не смотрели контакты contacts_show</a></span></li></ul></li><li><span><a href="#Проверка-гипотез" data-toc-modified-id="Проверка-гипотез-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Проверка гипотез</a></span><ul class="toc-item"><li><span><a href="#Проверка-гипотезы-о-различии-конверсии-в-просмотры-контактов-пользователей-совершивших-действия-tips_show-и-tips_click-и-пользователей-совершивших-только-действие-tips_show" data-toc-modified-id="Проверка-гипотезы-о-различии-конверсии-в-просмотры-контактов-пользователей-совершивших-действия-tips_show-и-tips_click-и-пользователей-совершивших-только-действие-tips_show-6.1"><span class="toc-item-num">6.1&nbsp;&nbsp;</span>Проверка гипотезы о различии конверсии в просмотры контактов пользователей совершивших действия tips_show и tips_click и пользователей совершивших только действие tips_show</a></span></li><li><span><a href="#Проверка-гипотезы-о-различии-конверсии-в-просмотры-контактов-пользователей-привлечённых-из-рекламного-источника-&quot;yandex&quot;-и-пользователей-привлечённых-из-рекламного-источника-&quot;google&quot;." data-toc-modified-id="Проверка-гипотезы-о-различии-конверсии-в-просмотры-контактов-пользователей-привлечённых-из-рекламного-источника-&quot;yandex&quot;-и-пользователей-привлечённых-из-рекламного-источника-&quot;google&quot;.-6.2"><span class="toc-item-num">6.2&nbsp;&nbsp;</span>Проверка гипотезы о различии конверсии в просмотры контактов пользователей привлечённых из рекламного источника "yandex" и пользователей привлечённых из рекламного источника "google".</a></span></li></ul></li><li><span><a href="#Общий-вывод" data-toc-modified-id="Общий-вывод-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>Общий вывод</a></span></li><li><span><a href="#Презентация-и-дашборд" data-toc-modified-id="Презентация-и-дашборд-8"><span class="toc-item-num">8&nbsp;&nbsp;</span>Презентация и дашборд</a></span></li></ul></div>

# %% [markdown]
# **Описание проекта**

# %% [markdown]
# В рамках данного проекта мы подготовим анализ поведения пользователей мобильного приложения «Ненужные вещи»,в котором пользователи продают свои ненужные вещи, размещая их на доске объявлений. Ответим на вопросы заказчика. Найдём инсайты, которые позволят нам стать лучшим приложением для продажи ненужных вещей. Проверим статистические гипотезы на разных группах пользователей.  Презентуем полученные результаты, которые в будущем помогут менеджерам продукта в проработке дальнейших мероприятий по улучшению приложения с точки зрения пользовательского опыта.

# %% [markdown]
# **Предоставленные файлы**

# %% [markdown]
# - `mobile_dataset.csv` - Лог сервера с информацией о действиях пользователей
#
# - `mobile_sources.csv` - Информация по идентификатору источника перехода пользователя в приложение

# %% [markdown]
# **Цель исследования**

# %% [markdown]
# - Проанализировать влияние событий на совершение целевого события.
#
# - Оценить поведение пользователей по данным для дальнейшего управления вовлеченностью клиентов (адаптация приложения по целевой и смежной аудитории). Наше исследование поведения пользователей подскажет заказчику,какая аудитория является целевой, а какая смежная путём сегментации пользователей на отдельные кластеры групп для дальнейшего точечного управления этими группами.
#
# - Получить на основе поведения пользователей гипотезы о том как можно было бы улучшить приложение с точки зрения пользовательского опыта. Проверить гипотезы и интерпретировать результат, который поможет выявить группы пользователей, где конверсия в целевое действие больше всего.
#
# - Дать рекомендации по результатам исследования.

# %% [markdown]
# **Основные шаги**

# %% [markdown]
# 1. Обзор данных
# 2. Предобработка данных
# 3. Исследовательский анализ данных
# 4. Анализ влияния действий на совершение целевого события
# 5. Оценка частоты действий пользователей просмотревших контакты
# 6. Проверка гипотез
# 7. Общий вывод

# %% [markdown]
# ## Обзор данных

# %%
# %%capture

#Установка библиотеки tqdm
# !pip install tqdm

#Установка менеджера пакетов pip для модуля kaleido
# %pip install -U kaleido -q

# %%
# импорт библиотек
import pandas as pd
import matplotlib.pyplot as plt
import math
import scipy.stats as st
import numpy as np
import warnings
import re
import plotly.express as px
import requests

# для генерации plotly графиков в изображение
import plotly.io as pio
pio.renderers.default = "png"

#импорт модуля graph_objects
from plotly import graph_objects as go

#импорт модуля tqdm
from tqdm import tqdm

#импорт  стат. теста proportions_ztest
from statsmodels.stats.proportion import proportions_ztest

# %%
# убираем системные предупреждения

warnings.filterwarnings('ignore')

# %% [markdown]
# ###  Считаем CSV-файлы  с данными

# %%
try:
    visits = pd.read_csv('D:\myuser\YandexPracticumfilesproject\mobile_dataset.csv')
    sources = pd.read_csv('D:\myuser\YandexPracticumfilesproject\mobile_sources.csv')

except:
    visits = pd.read_csv('https://code.s3.yandex.net/datasets/mobile_dataset.csv')
    sources = pd.read_csv('https://code.s3.yandex.net/datasets/mobile_sources.csv')

# %% [markdown]
# ### Выведем первые строки каждого набора данных и изучим общую информацию по каждому датафрейму

# %% [markdown]
# #### Журнал действий пользователей

# %%
display(visits.head(10))
visits.info()
# Out:
#                    event.time   event.name  \
# 0  2019-10-07 00:00:00.431357  advert_open
# 1  2019-10-07 00:00:01.236320    tips_show
# 2  2019-10-07 00:00:02.245341    tips_show
# 3  2019-10-07 00:00:07.039334    tips_show
# 4  2019-10-07 00:00:56.319813  advert_open
# 5  2019-10-07 00:01:19.993624    tips_show
# 6  2019-10-07 00:01:27.770232  advert_open
# 7  2019-10-07 00:01:34.804591    tips_show
# 8  2019-10-07 00:01:49.732803  advert_open
# 9  2019-10-07 00:01:54.958298  advert_open
#
#                                 user.id
# 0  020292ab-89bc-4156-9acf-68bc2783f894
# 1  020292ab-89bc-4156-9acf-68bc2783f894
# 2  cf7eda61-9349-469f-ac27-e5b6f5ec475c
# 3  020292ab-89bc-4156-9acf-68bc2783f894
# 4  cf7eda61-9349-469f-ac27-e5b6f5ec475c
# 5  cf7eda61-9349-469f-ac27-e5b6f5ec475c
# 6  020292ab-89bc-4156-9acf-68bc2783f894
# 7  020292ab-89bc-4156-9acf-68bc2783f894
# 8  cf7eda61-9349-469f-ac27-e5b6f5ec475c
# 9  020292ab-89bc-4156-9acf-68bc2783f894
# ...

# %% [markdown]
# В таблице три столбца:
# - **event.time** — время совершения действия пользователем
# - **event.name** — действие пользователя
# - **user.id** — идентификатор пользователя

# %% [markdown]
# По полученной информации видно следующее:
#
# - В столбце  event.time неверный тип данных, в процессе предобработки изменим тип данных на соответствующий значениям столбца.
# - Для убодства обращения к столбцам, в процессе предобработки данных, приведём их к нижнему регистру, 'змеиному' стилю написания.
# - Есть необходимость в добавлении столбца session_id  с информацией по сессиям пользователей.

# %% [markdown]
# #### Данные по источникам привлечения пользователей

# %%
display(sources.head(10))
sources.info()
# Out:
#                                  userId  source
# 0  020292ab-89bc-4156-9acf-68bc2783f894   other
# 1  cf7eda61-9349-469f-ac27-e5b6f5ec475c  yandex
# 2  8c356c42-3ba9-4cb6-80b8-3f868d0192c3  yandex
# 3  d9b06b47-0f36-419b-bbb0-3533e582a6cb   other
# 4  f32e1e2a-3027-4693-b793-b7b3ff274439  google
# 5  17f6b2db-2964-4d11-89d8-7e38d2cb4750  yandex
# 6  62aa104f-592d-4ccb-8226-2ba0e719ded5  yandex
# 7  57321726-5d66-4d51-84f4-c797c35dcf2b  google
# 8  c2cf55c0-95f7-4269-896c-931d14deaab5  google
# 9  48e614d6-fe03-40f7-bf9e-4c4f61c19f64  yandex
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4293 entries, 0 to 4292
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   userId  4293 non-null   object
#  1   source  4293 non-null   object
# dtypes: object(2)
# memory usage: 67.2+ KB

# %% [markdown]
# В таблице два столбца:
# - **userId** — идентификатор пользователя
# - **source** — источник привлечения пользователей

# %% [markdown]
# По полученной информации видно следующее:
#
# - Для убодства обращения к столбцам, в процессе предобработки данных, приведём их к нижнему регистру, 'змеиному' стилю написания.

# %% [markdown]
# **Вывод**
# В представленных для анализа файлах - данные о действиях пользователей и источниках их привлечения. Предварительно данных достаточно для анализа.
#
# Необходимые изменения:
#
# Исправим нарушения стиля (не соблюден snake case, присутствуют прописные буквы в наименованиях столбцов)
#
# Устраним несоотвествие типа данных в столбце `event.time` файла visits, с типа object на datetime.
#
# Добавим столбец `session_id` с информацией по сессиям пользователей.

# %% [markdown]
# ## Предобработка данных

# %% [markdown]
# ### Стиль заголовков

# %% [markdown]
# Переименование колонок таблицы `visits`

# %%
visits.columns
# Out:
# Index(['event.time', 'event.name', 'user.id'], dtype='object')

# %%
# Применим метод str.lower() для преобразования названий столбцов к нижнему регистру
visits.columns = visits.columns.str.lower()
visits = visits.rename(columns={'event.time':'event_time','event.name':'event_name','user.id':'user_id'})
visits.columns
# Out:
# Index(['event_time', 'event_name', 'user_id'], dtype='object')

# %% [markdown]
# Переименование колонок таблицы `sources`

# %%
sources.columns
# Out:
# Index(['userId', 'source'], dtype='object')

# %%
# Применим метод str.lower() для преобразования названий столбцов к нижнему регистру
sources.columns = sources.columns.str.lower()
sources = sources.rename(columns={'userid':'user_id'})
sources.columns
# Out:
# Index(['user_id', 'source'], dtype='object')

# %% [markdown]
# После преобразования названия колонок стали стилистически верные.

# %% [markdown]
# ### Объединение данных в один датафрейм

# %% [markdown]
# Для дальнейшего анализа и работы с данными, произведём  объединение таблиц в один датафрейм

# %%
# Объединим датафреймы в один методом merge() по столбцу 'user_id'
data = visits.merge(sources,on='user_id',how = 'left')
data.head()
# Out:
#                    event_time   event_name  \
# 0  2019-10-07 00:00:00.431357  advert_open
# 1  2019-10-07 00:00:01.236320    tips_show
# 2  2019-10-07 00:00:02.245341    tips_show
# 3  2019-10-07 00:00:07.039334    tips_show
# 4  2019-10-07 00:00:56.319813  advert_open
#
#                                 user_id  source
# 0  020292ab-89bc-4156-9acf-68bc2783f894   other
# 1  020292ab-89bc-4156-9acf-68bc2783f894   other
# 2  cf7eda61-9349-469f-ac27-e5b6f5ec475c  yandex
# 3  020292ab-89bc-4156-9acf-68bc2783f894   other
# 4  cf7eda61-9349-469f-ac27-e5b6f5ec475c  yandex

# %% [markdown]
# ### Обработка пропусков

# %% [markdown]
# Проверим наличие пропусков после объединения данных в один датафрейм

# %%
data.isna().sum()
# Out:
# event_time    0
# event_name    0
# user_id       0
# source        0
# dtype: int64

# %% [markdown]
# Пропуски не обнаружены

# %% [markdown]
# ###  Обработка явных  дубликатов

# %% [markdown]
# Для дальнейшей работы с данными найдем возможные явные дубликаты в датафрейме.

# %%
data.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ### Изменение типов данных

# %% [markdown]
# В ходе обзора данных был обнаружен неверный тип данных в столбце event_time.
# Устраним несоотвествие,изменим тип данных с object на datetime.

# %%
# Создаем новый столбец с датой и временем
data['event_time'] = pd.to_datetime(data['event_time'])

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 74197 entries, 0 to 74196
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   event_time  74197 non-null  datetime64[ns]
#  1   event_name  74197 non-null  object
#  2   user_id     74197 non-null  object
#  3   source      74197 non-null  object
# dtypes: datetime64[ns](1), object(3)
# memory usage: 2.3+ MB

# %% [markdown]
# Столбец приведён к формату даты и времени

# %% [markdown]
# ### Обработка аномальных значений

# %%
data.head(5)
# Out:
#                   event_time   event_name  \
# 0 2019-10-07 00:00:00.431357  advert_open
# 1 2019-10-07 00:00:01.236320    tips_show
# 2 2019-10-07 00:00:02.245341    tips_show
# 3 2019-10-07 00:00:07.039334    tips_show
# 4 2019-10-07 00:00:56.319813  advert_open
#
#                                 user_id  source
# 0  020292ab-89bc-4156-9acf-68bc2783f894   other
# 1  020292ab-89bc-4156-9acf-68bc2783f894   other
# 2  cf7eda61-9349-469f-ac27-e5b6f5ec475c  yandex
# 3  020292ab-89bc-4156-9acf-68bc2783f894   other
# 4  cf7eda61-9349-469f-ac27-e5b6f5ec475c  yandex

# %% [markdown]
# В рамках исследования найдём возможные аномальные значения по столбцам:

# %% [markdown]
# **Поиск аномалий по столбцу event_time**

# %%
data['event_time'].describe()
# Out:
# count                            74197
# mean     2019-10-21 15:32:09.039316992
# min         2019-10-07 00:00:00.431357
# 25%      2019-10-14 22:04:27.791869952
# 50%      2019-10-22 00:26:56.715014912
# 75%      2019-10-28 12:35:53.023877120
# max         2019-11-03 23:58:12.532487
# Name: event_time, dtype: object

# %% [markdown]
# Аномалия не выявлены

# %% [markdown]
# **Поиск аномалий по столбцу event_name**

# %%
data['event_name'].value_counts()
# Out:
# event_name
# tips_show        40055
# photos_show      10012
# advert_open       6164
# contacts_show     4450
# map               3881
# search_1          3506
# favorites_add     1417
# search_5          1049
# tips_click         814
# search_4           701
# contacts_call      541
# search_3           522
# search_6           460
# search_2           324
# search_7           222
# show_contacts       79
# Name: count, dtype: int64

# %% [markdown]
# Были обнуружены повторяющиеся действия:
# 1. `contacts_show и show_contacts`. Заказчик сообщил, что это одно и тоже действие пользователей.Данные были выгружены из разных баз данных. В дальнейшем объединим эти категории действий в одну.
#
# 2. `search_1,search_2,search_3,search_4,search_5,search_6,search_7`. Данные действия трактуются, как поисковые запросы пользователей в приложении по разным разделам. Заказчик не предоставил расшифровку действий. В дальнейшем объединим эти категории действий в одну.

# %% [markdown]
# Объединим категории contacts_show и show_contacts в одну `contacts_show`

# %%
data['event_name'].where(data['event_name'] != 'show_contacts', 'contacts_show',inplace=True)

# %% [markdown]
# Объединим категории search_1,search_2,search_3,search_4,search_5,search_6,search_7 в одну `search_1`

# %%
data['event_name'].replace(['search_1','search_2','search_3','search_4','search_5','search_6','search_7'],'search_1',inplace=True)

# %%
data['event_name'].value_counts()
# Out:
# event_name
# tips_show        40055
# photos_show      10012
# search_1          6784
# advert_open       6164
# contacts_show     4529
# map               3881
# favorites_add     1417
# tips_click         814
# contacts_call      541
# Name: count, dtype: int64

# %% [markdown]
# Категории действий пользователей успешно укрупнены

# %% [markdown]
# **Поиск аномалий по столбцу source**

# %%
data['source'].value_counts()
# Out:
# source
# yandex    34286
# google    20445
# other     19466
# Name: count, dtype: int64

# %% [markdown]
# Аномалия не выявлены

# %% [markdown]
# ###  Обработка неявных  дубликатов

# %% [markdown]
# Для дальнейшей работы с данными найдем возможные неявные дубликаты в датафрейме совпадающие по времени совершения действия пользователем и категории действия пользователя одновременно

# %%
data.duplicated(subset=['event_time','event_name']).sum()
# Out:
# 0

# %% [markdown]
# Также найдем возможные неявные дубликаты в датафрейме совпадающие по идентификатору пользователя  и  источнику привлечения пользователя одновременно

# %%
sources.duplicated(subset=['user_id','source']).sum()
# Out:
# 0

# %% [markdown]
# Неявные дубликаты не выявлены

# %% [markdown]
# ### Добавление столбцов

# %% [markdown]
# В рамках дальнейшего анализа есть необходимость в добавлении столбца `session_id` с информацией по сессиям пользователей, а также отдельного столбца `event_date` с датой совершения действия пользователем.

# %% [markdown]
# #### Добавление столбца session_id

# %% [markdown]
# Перед тем, как добавлять столбец `session_id` нам необходимо понять какое распределение времени между соседними событиями у пользователей. Для этого мы должны добавить столбец  `duration_event` с разницей событий по пользователю в минутах.

# %%
data = data.sort_values(['user_id', 'event_time'])

# %%
data
# Out:
#                       event_time     event_name  \
# 805   2019-10-07 13:39:45.989359      tips_show
# 806   2019-10-07 13:40:31.052909      tips_show
# 809   2019-10-07 13:41:05.722489      tips_show
# 820   2019-10-07 13:43:20.735461      tips_show
# 830   2019-10-07 13:45:30.917502      tips_show
# ...                          ...            ...
# 72584 2019-11-03 15:51:23.959572      tips_show
# 72589 2019-11-03 15:51:57.899997  contacts_show
# 72684 2019-11-03 16:07:40.932077      tips_show
# 72688 2019-11-03 16:08:18.202734      tips_show
# 72689 2019-11-03 16:08:25.388712      tips_show
#
#                                     user_id  source
# 805    0001b1d5-b74a-4cbf-aeb0-7df5947bf349   other
# 806    0001b1d5-b74a-4cbf-aeb0-7df5947bf349   other
# 809    0001b1d5-b74a-4cbf-aeb0-7df5947bf349   other
# 820    0001b1d5-b74a-4cbf-aeb0-7df5947bf349   other
# 830    0001b1d5-b74a-4cbf-aeb0-7df5947bf349   other
# ...                                     ...     ...
# ...

# %%
data['event_time_previous'] = data.groupby('user_id')['event_time'].shift(1)
data['duration_event'] = (data['event_time'] - data['event_time_previous']).dt.total_seconds()/60
data.head(50)
# Out:
#                       event_time     event_name  \
# 805   2019-10-07 13:39:45.989359      tips_show
# 806   2019-10-07 13:40:31.052909      tips_show
# 809   2019-10-07 13:41:05.722489      tips_show
# 820   2019-10-07 13:43:20.735461      tips_show
# 830   2019-10-07 13:45:30.917502      tips_show
# 831   2019-10-07 13:45:43.212340      tips_show
# 832   2019-10-07 13:46:31.033718      tips_show
# 836   2019-10-07 13:47:32.860234      tips_show
# 839   2019-10-07 13:49:41.716617      tips_show
# 6541  2019-10-09 18:33:55.577963            map
# 6546  2019-10-09 18:35:28.260975            map
# 6565  2019-10-09 18:40:28.738785      tips_show
# 6566  2019-10-09 18:42:22.963948      tips_show
# 36412 2019-10-21 19:52:30.778932      tips_show
# 36416 2019-10-21 19:53:17.165009      tips_show
# 36419 2019-10-21 19:53:38.767230            map
# 36421 2019-10-21 19:54:45.009859      tips_show
# 36423 2019-10-21 19:54:56.854811      tips_show
# ...

# %% [markdown]
# Найдём крайние процентили распределения временных промежутков по созданному столбцу `duration_event`.

# %%
np.nanpercentile(data['duration_event'],[80,81,82,83,84,85,86,87,88,89,90,90.5,91,91.5,92,92.5,93,94])
# Out:
# array([  4.03354062,   4.34036789,   4.67465271,   5.12753836,
#          5.64117662,   6.24513117,   7.12049798,   8.35075945,
#         10.0259776 ,  12.59672191,  17.01345773,  20.52016434,
#         25.74052284,  33.5171113 ,  45.42175091,  62.41421535,
#         89.98816264, 211.54434016])

# %% [markdown]
# Основываясь на полученные значения, нехарактерным временем между соседними событиями пользователя можно считать временные диапазоны бездействия пользователя,  более 89 процентиля (12.59672191 минут).  Так как по следующим процентилям идёт сильный разброс полученного времени, оно нехарактерно для действий пользователя в одной сессии.

# %% [markdown]
# Посмотрим распределение временных промежутков между событиями на графике

# %%
# строим график
fig = px.histogram(data,
                   x='duration_event',
                   color_discrete_sequence=px.colors.qualitative.Pastel,
                   nbins=50000)

# оформляем график
fig.update_layout(title='Распределение временных промежутков между событиями',
                  xaxis=dict(range=[0, 40]),
                  title_x=0.45,
                  xaxis_title='Время промежутка (мин)',
                  yaxis_title='Кол-во промежутков',
                  width=1000, # указываем размеры графика
                  height=600,
                  yaxis_title_font=dict(size=16),
                  xaxis_title_font=dict(size=16),
                  title_font=dict(size=20))

# повернём подписи по оси X на 45 градусов
fig.update_xaxes(tickangle=45)
fig.show() # выводим график

# %% [markdown]
# Гистограмма, показывает нам, что нехарактерное время между соседними событиями более 10 мин. Частота встречаемости таких промежутков менее 300 ед. и продолжает уменьшаться с увеличением длительности времени между соседними событиями.

# %%
#Удалим ненужные столбцы после отрисовки графика
data = data.drop(columns=['event_time_previous','duration_event'])
data
# Out:
#                       event_time     event_name  \
# 805   2019-10-07 13:39:45.989359      tips_show
# 806   2019-10-07 13:40:31.052909      tips_show
# 809   2019-10-07 13:41:05.722489      tips_show
# 820   2019-10-07 13:43:20.735461      tips_show
# 830   2019-10-07 13:45:30.917502      tips_show
# ...                          ...            ...
# 72584 2019-11-03 15:51:23.959572      tips_show
# 72589 2019-11-03 15:51:57.899997  contacts_show
# 72684 2019-11-03 16:07:40.932077      tips_show
# 72688 2019-11-03 16:08:18.202734      tips_show
# 72689 2019-11-03 16:08:25.388712      tips_show
#
#                                     user_id  source
# 805    0001b1d5-b74a-4cbf-aeb0-7df5947bf349   other
# 806    0001b1d5-b74a-4cbf-aeb0-7df5947bf349   other
# 809    0001b1d5-b74a-4cbf-aeb0-7df5947bf349   other
# 820    0001b1d5-b74a-4cbf-aeb0-7df5947bf349   other
# 830    0001b1d5-b74a-4cbf-aeb0-7df5947bf349   other
# ...                                     ...     ...
# ...

# %% [markdown]
# Нам необходимо добавить столбец `session_id` с целью выделения пользовательских сессий. Исходя из полученных данных, промежутки бездействия пользователя, превышающие 89 процентиль (12.59672191 минут), можно считать необычно длительными между событиями, полученный график это подтверждает. В связи с значительным разбросом времени, полученного для последующих процентилей, такие интервалы не типичны для пользовательских действий в рамках одной сессии. Примем решение и установим временем окончания сессии  временной промежуток от 13 мин бездействия пользователя в приложении, с момента совершения последнего действия.
# Данный временной промежуток является оптимальным для понимания об окончании пользовательской сессии.

# %%
data = data.sort_values(['user_id', 'event_time'])
#identify difference 13Min for each group with cumulative sum
g = (data.groupby('user_id')['event_time'].diff() > pd.Timedelta('13Min')).cumsum()
#create counter of groups
data['session_id'] = data.groupby(['user_id', g], sort=False).ngroup() + 1
data['session_id'].nunique()
# Out:
# 11893

# %% [markdown]
# В результате получилось 11893 сессий

# %% [markdown]
# #### Добавление столбца event_date

# %%
data['event_date'] = data['event_time'].dt.date

# %% [markdown]
# Столбец успешно добавлен

# %% [markdown]
# #### Добавление столбца с номером недели

# %%
data['event_week'] = data['event_time'].dt.isocalendar().week

# %% [markdown]
# Столбец успешно добавлен

# %% [markdown]
# ### Изменение порядка расположения столбцов

# %% [markdown]
# Изменим порядок расположения столбцов для более логичного восприятия таблицы

# %%
data = data[['user_id','event_time','event_date','event_week','event_name','session_id','source']]

# %%
data.head(5)
# Out:
#                                   user_id                 event_time  \
# 805  0001b1d5-b74a-4cbf-aeb0-7df5947bf349 2019-10-07 13:39:45.989359
# 806  0001b1d5-b74a-4cbf-aeb0-7df5947bf349 2019-10-07 13:40:31.052909
# 809  0001b1d5-b74a-4cbf-aeb0-7df5947bf349 2019-10-07 13:41:05.722489
# 820  0001b1d5-b74a-4cbf-aeb0-7df5947bf349 2019-10-07 13:43:20.735461
# 830  0001b1d5-b74a-4cbf-aeb0-7df5947bf349 2019-10-07 13:45:30.917502
#
#      event_date  event_week event_name  session_id source
# 805  2019-10-07          41  tips_show           1  other
# 806  2019-10-07          41  tips_show           1  other
# 809  2019-10-07          41  tips_show           1  other
# 820  2019-10-07          41  tips_show           1  other
# 830  2019-10-07          41  tips_show           1  other

# %% [markdown]
# **Вывод**
# - Наименования столбцов приведены к нижнему,змеиному регистру. Порядок расположения столбцов выстроен логично.
# - Таблицы объединены в один датафрейм.
# - Пропуски не выявлены.
# - Явные дубликаты не выявлены.
# - Столбец `event_time` приведён к формату даты и времени.
# - Категории действий пользователей укрупнены.
# - Неявные дубликаты не выявлены.
# - Добавлены:
#   - столбец session_id с информацией по сессиям пользователей
#   - столбец event_date с информацией по дате совершения действия пользователем
#   - столбец event_week с информацией по номеру недели совершения действия пользователем

# %% [markdown]
# ##  Исследовательский анализ данных

# %% [markdown]
# В рамках дальнейшего анализа изучим и проверим полученные данные.Найдём зависимости и особенности. Соберём наблюдения в один общий вывод.

# %% [markdown]
# ### Профили пользователей

# %% [markdown]
# Узнаем минимальную и максимальную дату совершения первого действия.

# %%
display(data.loc[data['event_time'] == data['event_time'].min()])
data.loc[data['event_time'] == data['event_time'].max()]
# Out:
#                                 user_id                 event_time  \
# 0  020292ab-89bc-4156-9acf-68bc2783f894 2019-10-07 00:00:00.431357
#
#    event_date  event_week   event_name  session_id source
# 0  2019-10-07          41  advert_open          83  other
#                                     user_id                 event_time  \
# 74196  28fccdf4-7b9e-42f5-bc73-439a265f20e9 2019-11-03 23:58:12.532487
#
#        event_date  event_week event_name  session_id  source
# 74196  2019-11-03          44  tips_show        2098  google

# %% [markdown]
# - Первое действие произошло 2019-10-07 в  00:00:00.431357 миллисекунд
# - Последнее действие произошло 2019-11-03 в 23:58:12.532487 миллисекунд

# %%
print(f" Анализируемый период составил {(data['event_time'].max()) - (data['event_time'].min())}")
# Out:
#  Анализируемый период составил 27 days 23:58:12.101130

# %% [markdown]
# ### Количество действий и сессий в логе

# %% [markdown]
# Узнаем сколько всего действий и сессий в наших данных

# %%
print(f" Общее количество совершённых действий пользователями {len(data)}")
print(f" Общее количество сессий пользователей {data['session_id'].nunique()}")
# Out:
#  Общее количество совершённых действий пользователями 74197
#  Общее количество сессий пользователей 11893

# %% [markdown]
# ### Количество уникальных пользователей в логе

# %% [markdown]
# Найдём число уникальных пользователей за весь период

# %%
print(f" Число уникальных пользователей за весь период составило {data['user_id'].nunique()}")
# Out:
#  Число уникальных пользователей за весь период составило 4293

# %% [markdown]
# ### Количество действий  на пользователя

# %% [markdown]
# Найдём среднее,медианное,минимальное,максимальное количество действий на одного пользователя.Сделаем выводы.

# %%
print(f" Cреднее количество действий на одного пользователя"
      f" {int(round(data.groupby('user_id').agg({'event_name':'count'})['event_name'].mean(), 0))}")
print(f" Медианное количество действий на одного пользователя"
      f" {int(round(data.groupby('user_id').agg({'event_name':'count'})['event_name'].median(), 0))}")
print(f" Минимальное количество действий на одного пользователя"
      f" {int(data.groupby('user_id').agg({'event_name':'count'})['event_name'].min())}")
print(f" Максимальное количество действий на одного пользователя"
      f" {int(data.groupby('user_id').agg({'event_name':'count'})['event_name'].max())}")
# Out:
#  Cреднее количество действий на одного пользователя 17
#  Медианное количество действий на одного пользователя 9
#  Минимальное количество действий на одного пользователя 1
#  Максимальное количество действий на одного пользователя 478

# %%
# строим график
fig = px.histogram(data.groupby('user_id').agg({'event_name':'count'})['event_name'],
                   x='event_name',
                   color_discrete_sequence=px.colors.qualitative.Pastel,
                   nbins=478)

# оформляем график
fig.update_layout(title='Распределение пользователей по количеству действий',
                  title_x=0.45,
                  xaxis_title='Кол-во действий на одного пользователя',
                  yaxis_title='Кол-во пользователей',
                  width=1000, # указываем размеры графика
                  height=600,
                  yaxis_title_font=dict(size=16),
                  xaxis_title_font=dict(size=16),
                  title_font=dict(size=20))

# повернём подписи по оси X на 45 градусов
fig.update_xaxes(tickangle=45)
fig.show() # выводим график

# %% [markdown]
# В наших логах присутствуют пользователи с аномально большим кол-ом действий.К примеру в данных есть пользователь совершивший 478 действий. Из-за этого разница в медианном и среднем значении составляет 8 действий на одного пользователя,это говорит нам о том, что действия по пользователям распределены по принципу  смещенного нормального распределения, это же подтверждает гистограмма.Рассмотрим график ограничив ось х до 100 действий.

# %%
# строим график
fig = px.histogram(data.groupby('user_id').agg({'event_name':'count'})['event_name'],
                   x='event_name',
                   color_discrete_sequence=px.colors.qualitative.Pastel,
                   nbins=478)

# оформляем график
fig.update_layout(title='Распределение пользователей по числу действий',
                  xaxis=dict(range=[0, 100]),
                  title_x=0.45,
                  xaxis_title='Кол-во действий на одного пользователя',
                  yaxis_title='Кол-во пользователей',
                  width=1000, # указываем размеры графика
                  height=600,
                  yaxis_title_font=dict(size=16),
                  xaxis_title_font=dict(size=16),
                  title_font=dict(size=20))

# повернём подписи по оси X на 45 градусов
fig.update_xaxes(tickangle=45)
fig.show() # выводим график

# %% [markdown]
# В целом,пик пользователей приходится от 4 до 6 действий на человека, таких пользователей от 368 до 472 ч. на каждое уникальное число действий.Далее следует планомерное снижение без локальных пиков на гистограмме.

# %%
np.percentile(data.groupby('user_id').agg({'event_name':'count'})['event_name'], [95, 99])
# Out:
# array([ 59., 132.])

# %% [markdown]
# Не более 5% пользователей совершили 59 действий и не более 1% совершили 132.

# %% [markdown]
# ### Количество сессий на пользователя

# %% [markdown]
# Найдём среднее,медианное,минимальное,максимальное количество сессий на одного пользователя.Сделаем выводы.

# %%
print(f" Cреднее количество сессий на одного пользователя {int(round(data.groupby('user_id').agg({'session_id':'nunique'})['session_id'].mean(), 0))}")
print(f" Медианное количество сессий на одного пользователя {int(round(data.groupby('user_id').agg({'session_id':'nunique'})['session_id'].median(), 0))}")
print(f" Минимальное количество сессий на одного пользователя {int(data.groupby('user_id').agg({'session_id':'nunique'})['session_id'].min())}")
print(f" Максимальное количество сессий на одного пользователя {int(data.groupby('user_id').agg({'session_id':'nunique'})['session_id'].max())}")
# Out:
#  Cреднее количество сессий на одного пользователя 3
#  Медианное количество сессий на одного пользователя 2
#  Минимальное количество сессий на одного пользователя 1
#  Максимальное количество сессий на одного пользователя 119

# %%
# строим график
fig = px.histogram(data.groupby('user_id').agg({'session_id':'nunique'})['session_id'],
                   x='session_id',
                   color_discrete_sequence=px.colors.qualitative.Pastel,
                   nbins=119)

# оформляем график
fig.update_layout(title='Распределение пользователей по количеству сессий',
                  title_x=0.45,
                  xaxis_title='Кол-во сессий на одного пользователя',
                  yaxis_title='Кол-во пользователей',
                  width=1000, # указываем размеры графика
                  height=600,
                  yaxis_title_font=dict(size=16),
                  xaxis_title_font=dict(size=16),
                  title_font=dict(size=20))

# повернём подписи по оси X на 45 градусов
fig.update_xaxes(tickangle=45)
fig.show() # выводим график

# %% [markdown]
# Основная часть пользователей совершила не более 5 сессий за 27 дней использования приложения. Более 17 сессий у единичного числа пользователей. Пик пользователей приходится на 1 сессию, таких пользователей 2007ч.График гистограммы имеет вид смещенного с длинным правым хвостом из-за выбросов.

# %%
np.percentile(data.groupby('user_id').agg({'session_id':'nunique'})['session_id'], [95, 99])
# Out:
# array([ 8., 20.])

# %% [markdown]
# Не более 5% пользователей совершили 8 сессий и не более 1% совершили 20.

# %% [markdown]
# ### Длительность сессии пользователя

# %% [markdown]
# Узнаем сколько времени длится сессия (мин.) пользователей в разрезе источника привлечения

# %%
duration_session = data.pivot_table(index=['session_id'],
                                    values=['event_time','source','user_id'],
                                    aggfunc={'event_time':['first','last'],
                                             'source':'first',
                                             'user_id':'first'})


duration_session.columns=['event_time_start','event_time_finish','source','user_id']
duration_session.reset_index()
duration_session['session_duration'] = (duration_session['event_time_finish'] - duration_session['event_time_start'])
duration_session['session_duration'] = duration_session['session_duration'].dt.total_seconds() / 60
duration_session
# Out:
#                      event_time_start          event_time_finish  source  \
# session_id
# 1          2019-10-07 13:39:45.989359 2019-10-07 13:49:41.716617   other
# 2          2019-10-09 18:33:55.577963 2019-10-09 18:42:22.963948   other
# 3          2019-10-21 19:52:30.778932 2019-10-21 20:07:30.051028   other
# 4          2019-10-22 11:18:14.635436 2019-10-22 11:30:52.807203   other
# 5          2019-10-19 21:34:33.849769 2019-10-19 21:59:54.637098  yandex
# ...                               ...                        ...     ...
# 11889      2019-11-02 18:17:41.386651 2019-11-02 18:17:41.386651  google
# 11890      2019-11-02 19:25:53.794029 2019-11-02 19:30:50.471310  google
# 11891      2019-11-03 14:32:55.956301 2019-11-03 14:48:44.263356  google
# 11892      2019-11-03 15:36:01.007440 2019-11-03 15:51:57.899997  google
# 11893      2019-11-03 16:07:40.932077 2019-11-03 16:08:25.388712  google
#
#                                          user_id  session_duration
# session_id
# ...

# %%
#Строим график
fig = px.violin(duration_session,
                y='session_duration',
                x='source',
                box=True,
                hover_data=duration_session.columns,
                color='source',
                color_discrete_sequence=px.colors.qualitative.Pastel)

# оформляем график
fig.update_layout(title='Распределение длительности сессий по источникам привлечения',
                  title_x=0.45,
                  xaxis_title='Источник привлечения',
                  yaxis_title='Длительность сессий в минутах ',
                  width=1000, # указываем размеры графика
                  height=600,
                  yaxis_title_font=dict(size=16),
                  xaxis_title_font=dict(size=16),
                  title_font=dict(size=20))




# оформляем график
fig.update_traces(meanline_visible=True)
fig.update_yaxes(zeroline=False)
fig.update_xaxes(tickangle=45)
fig.show()

# %% [markdown]
# По всем источникам привлечения наблюдаются выбросы с длинными сессиями по отдельно взятым пользователям.Выделить конкретный источник нельзя.Детальная информация доступна при наведении курсора на любой из выбросов.Рассмотрим распределения в крупном масштабе, ограничев длительность сессии 50-ю минутами.

# %%
#Строим график
fig = px.box(duration_session,
                y='session_duration',
                x='source',
                hover_data=duration_session.columns,
                color='source',
                color_discrete_sequence=px.colors.qualitative.Pastel)

# оформляем график
fig.update_layout(title='Распределение длительности сессий по источникам привлечения',
                  title_x=0.45,
                  xaxis_title='Источник привлечения',
                  yaxis_title='Длительность сессий в минутах ',
                  width=1000, # указываем размеры графика
                  height=600,
                  yaxis_title_font=dict(size=16),
                  xaxis_title_font=dict(size=16),
                  title_font=dict(size=20))




# оформляем график
fig.update_xaxes(tickangle=45)
fig.update_yaxes(range=[0, 50])
fig.show()

# %% [markdown]
# Пользователи из источника привлечения "yandex" имеют самое большое медианное значение длительности сессии на пользователя, длительность составила 4.68 мин. На втором месте "google" с длительностью 4.09 мин. Пользователи перешедшие с источника привлечения "other" меньше всего проводят времени за одну сессию, всего ~ 3 мин. Возможно, это так называемые "organic" пользователи, которые пришли в приложение самостоятельно, они же и менее качественные.

# %% [markdown]
# ### Оценка пользовательской активности DAU,WAU

# %% [markdown]
# Узнаем пользовательскую активность. Посчитаем количество уникальных активных пользователей в разрезе каждого дня и недели.

# %% [markdown]
# Посчитаем DAU и WAU. Сгруппируем данные по дате и неделе, посчитаем количество уникальных пользователей по столбцу user_id и найдём среднее.

# %%
dau_total = (
    data.groupby('event_date').agg({'user_id': 'nunique'}).reset_index()
)

wau_total = (
    data.groupby('event_week').agg({'user_id': 'nunique'}).reset_index()
)

print(f'Среднее количество уникальных пользователей в день {int(dau_total["user_id"].mean())}')
print(f'Среднее количество уникальных пользователей в неделю {int(wau_total["user_id"].mean())}')
# Out:
# Среднее количество уникальных пользователей в день 279
# Среднее количество уникальных пользователей в неделю 1382

# %% [markdown]
# Построим график изменения DAU во времени

# %%
fig = px.line(dau_total,
              x="event_date",
              y="user_id",
              markers=True,
              color_discrete_sequence=px.colors.qualitative.Pastel)

# оформляем график
fig.update_layout(title='DAU',
                  title_x=0.45,
                  xaxis_title='Дата',
                  yaxis_title='Количество уникальных активных пользователей',
                  width=1000, # указываем размеры графика
                  height=600,
                  yaxis_title_font=dict(size=16),
                  xaxis_title_font=dict(size=16),
                  title_font=dict(size=20))




# оформляем график
fig.show()

# %% [markdown]
# Количество уникальных пользователей ежедневно изменяется, однако наблюдается общая тенденция к увеличению. 7 Октября 2019г. число уникальных активных пользователей составило 204 ч. 23 Октября 2019г. было зафиксировано пиковое значение в 352 ч. На конец анализа значение 285.

# %% [markdown]
# Построим график изменения WAU во времени

# %%
fig = px.line(wau_total,
              x="event_week",
              y="user_id",
              markers=True,
              color_discrete_sequence=px.colors.qualitative.Pastel)

# оформляем график
fig.update_layout(title='WAU',
                  title_x=0.45,
                  xaxis_title='Номер недели',
                  yaxis_title='Количество уникальных активных пользователей',
                  width=1000, # указываем размеры графика
                  height=600,
                  yaxis_title_font=dict(size=16),
                  xaxis_title_font=dict(size=16),
                  title_font=dict(size=20))




# оформляем график
fig.show()

# %% [markdown]
# С первой по вторую неделю наблюдается самый бурный рост числа уникальных,активных пользователей.К концу первой недели зафиксировано более 1400 пользователей. К концу третьей недели достигнут пик в 1546 пользователей. По последней неделе (с 27 октября 2019 г. по 3 ноября 2019г. наблюдается тренд на снижение пользовательской активности, абсолютное значение составляет 1416 пользователей.

# %% [markdown]
# ### Распределение привлеченных пользователей по источникам

# %% [markdown]
# Посмотрим распределение пользователей по каналам привлечения.Узнаем каких пользователей больше.Для этого построим интерактивную круговую диаграмму.

# %%
#Палитра цветов
pastel_colors = ['#55E6C1','#FEA47F','#7ed6df']

#Строим график
fig = go.Figure(data=[go.Pie(
                labels=['google','other','yandex'],
                values=data.groupby('source')['user_id'].nunique(),
                pull=[0,0,0.1],
                marker=dict(colors=pastel_colors))])  # Указываем палитру цветов

#оформляем график
fig.update_layout(title='Распределение привлеченных пользователей по источникам',
                  title_x=0.45,
                  width=1000, # указываем размеры графика
                  height=600,
                  title_font=dict(size=20),
                  annotations=[dict(
                                    x=1.12,
                                    y=1.05,
                                    text='Канал привлечения',
                                    showarrow=False)])

fig.show()

# %% [markdown]
# Круговая диаграмма показывает, что доля пользователей из канала привлечения "yandex" наибольшая среди всех. Доля составляет 45.1%, при абсолютном значении в 1934ч. Доли  источников "other" и "google" составляют 28.7% и 26.3% соответственно

# %% [markdown]
# ### Доли совершённых действий по пользователям

# %% [markdown]
# Построим график с распределением пользователей по совершённым действиям

# %%
action_user = data.pivot_table(index='event_name',values='user_id',aggfunc={'user_id':'count'}).reset_index().sort_values(by='user_id',ascending=False)
action_user.columns=['event_name','count']
action_user['share%'] = round((action_user['count']/action_user['count'].sum())*100,2)
action_user
# Out:
#       event_name  count  share%
# 8      tips_show  40055   53.98
# 5    photos_show  10012   13.49
# 6       search_1   6784    9.14
# 0    advert_open   6164    8.31
# 2  contacts_show   4529    6.10
# 4            map   3881    5.23
# 3  favorites_add   1417    1.91
# 7     tips_click    814    1.10
# 1  contacts_call    541    0.73

# %%
#Строим график
fig = px.bar(action_user,
             x='event_name',
             y='share%',
             hover_data=action_user.columns,
             color='event_name',
             color_discrete_sequence=px.colors.qualitative.Pastel)

# оформляем график
fig.update_layout(title='Распределение совершённых действий по пользователям',
                  title_x=0.45,
                  xaxis_title='Название действия',
                  yaxis_title='% совершённых действий',
                  width=1000, # указываем размеры графика
                  height=600,
                  yaxis_title_font=dict(size=16),
                  xaxis_title_font=dict(size=16),
                  title_font=dict(size=20))

fig.update_xaxes(tickangle=45)
fig.show() # выводим график

# %% [markdown]
# Более 50% всех действий пользователей приходится на `tips_show` при абсолютном значении в <40000 совершённых действий.Событие `tips_show` отображается автоматически для всех пользователей и не зависит от их действий. Целевое действие `contacts_show` занимает 6.1% от всех совершаемых действий при абсолютном значении в 4529. Наименьшая доля приходится на `contacts_call`, менее 1%. Это может говорить нам о том,что пользователи не звонят напрямую из нашего приложения, а копируют телефонный номер.

# %% [markdown]
# ### Доля сессий с целевым действием

# %% [markdown]
# Узнаем процентное соотношение сессий с целевым действием и без него.

# %%
print(f" Общее количество сессий пользователей {data['session_id'].nunique()}")
# Out:
#  Общее количество сессий пользователей 11893

# %%
print(f"Количество сессий с событием 'contacts_show': {data.loc[data['event_name'] == 'contacts_show']['session_id'].nunique()}")
# Out:
# Количество сессий с событием 'contacts_show': 1900

# %%
print(f"Количество сессий без события 'contacts_show': {data[~data['session_id'].isin(data.loc[data['event_name'] == 'contacts_show']['session_id'].unique())]['session_id'].nunique()}")
# Out:
# Количество сессий без события 'contacts_show': 9993

# %%
use_contacts_show = data.loc[data['event_name'] == 'contacts_show']['session_id'].nunique()

# %%
not_used_contacts_show = data[~data['session_id'].isin(data.loc[data['event_name'] == 'contacts_show']['session_id'].unique())]['session_id'].nunique()

# %% [markdown]
# Посмотрим процентное соотношение сессий с целевым действием и без. Для этого построим интерактивную круговую диаграмму.

# %%
#Палитра цветов
pastel_colors = ['#55E6C1','#FEA47F']

#Строим график
fig = go.Figure(data=[go.Pie(
                labels=['use_contacts_show','not_used_contacts_show'],
                values=(use_contacts_show,not_used_contacts_show),
                pull=[0,0.1],
                marker=dict(colors=pastel_colors))])  # Указываем палитру цветов

#оформляем график
fig.update_layout(title='Доля сессий с целевым действием и без',
                  title_x=0.45,
                  width=1000, # указываем размеры графика
                  height=600,
                  title_font=dict(size=20),
                  annotations=[dict(
                                    x=1.25,
                                    y=1.05,
                                    text='Действие пользователя',
                                    showarrow=False)])

fig.show()

# %% [markdown]
# В каждой шестой сессии пользователь просматривает контакты в объявлении.Процентная величина составила 16%, при абсолютном значении  в 1900 сессий. Численность сессий, где пользователь не смотрел контакты в объявлении составила 9993ч.  при доле в 84%

# %% [markdown]
# **Вывод**
#
# Мы провели исследовательский анализ данных пользователей мобильного приложения «Ненужные вещи» и нашли некоторые особенности, зависимости.
#
# 1. Анализируемый период составил 27 дней    С `2019-10-07 00:00:00` по `2019-11-03 23:58:12`
# 2. Общее количество совершённых действий пользователями 74197
# 3. Общее количество сессий пользователей 11893
# 4. Число уникальных пользователей за весь период составило 4293
# 5. Пик пользователей приходится от 4 до 6 действий на человека. Количество действий на пользователя:
#    - Cреднее количество действий на одного пользователя 17
#    - Медианное количество действий на одного пользователя 9
#    - Минимальное количество действий на одного пользователя 1
#    - Максимальное количество действий на одного пользователя 478
# 6. Пик пользователей приходится на 1 сессию. Основная часть пользователей совершила не более 5 сессий за 27 дней использования приложения. Количество сессий на пользователя:
#    - Cреднее количество сессий на одного пользователя 3
#    - Медианное количество сессий на одного пользователя 2
#    - Минимальное количество сессий на одного пользователя 1
#    - Максимальное количество сессий на одного пользователя 119
# 7. Пользователи из источника привлечения "yandex" имеют самое большое медианное значение длительности сессии на пользователя, длительность составила 4.68 мин. На втором месте "google" с длительностью 4.09 мин. Пользователи перешедшие с источника привлечения "other" меньше всего проводят времени за одну сессию, всего ~ 3 мин.
# 8. Среднее количество уникальных пользователей в день 279. Среднее количество уникальных пользователей в неделю 1382. По последней неделе (с 27 октября 2019 г. по 3 ноября 2019г. наблюдается тренд на снижение пользовательской активности, абсолютное значение составляет 1416 пользователей. Однако график DAU отражает общий тренд на увеличение пользовательской активности.
# 9. Доля пользователей из канала привлечения "yandex" наибольшая среди всех. Доля составляет 45.1%, при абсолютном значении в 1934ч. Доли источников "other" и "google" составляют 28.7% и 26.3% соответственно.
# 10. Более 50% всех действий пользователей приходится на tips_show при абсолютном значении в <40000 совершённых действий. Событие tips_show отображается автоматически для всех пользователей и не зависит от их действий. Целевое действие contacts_show занимает 6.1% от всех совершаемых действий при абсолютном значении в 4529. Наименьшая доля приходится на contacts_call, менее 1%. Это может говорить нам о том,что пользователи не звонят напрямую из нашего приложения, а копируют телефонный номер.
# 11. В каждой шестой сессии пользователь просматривает контакты в объявлении.Процентная величина составила 16%, при абсолютном значении в 1900 сессии.

# %% [markdown]
# ## Анализ влияния действий на совершение целевого события

# %% [markdown]
# Проведём анализ влияния всех действий пользователей на совершение целевого события.

# %% [markdown]
# ### Топ 4 сценария просмотра контактов пользователя

# %% [markdown]
# Нам необходимо визуализировать действия пользователей нашего мобильного приложения и найти топ-4 сценария просмотра контактов пользователя. Нужно понять, какие сценарии работы с приложением самые популярные и внимательнее рассмотреть действия пользователей на каждом шаге для дальнейшего улучшения стабильности работы приложения. Визуализируем полученную информацию с помощью диаграммы Санкея.

# %% [markdown]
# Для корректного построения сценариев, мы должны удалить повторяющиеся события пользователей в рамках сессий. Посмотрим их кол-во.

# %%
data.duplicated(subset=['session_id','event_name']).sum()
# Out:
# 54638

# %% [markdown]
# Удалим строки, где есть повторяющиеся значения в столбцах 'session_id', 'event_name' и оставим первую встретившуюся строку с повтором.

# %%
data_filtred = data.drop_duplicates(subset=['session_id','event_name'],keep='first')
data_filtred = data_filtred.reset_index(drop=True)
data_filtred
# Out:
#                                     user_id                 event_time  \
# 0      0001b1d5-b74a-4cbf-aeb0-7df5947bf349 2019-10-07 13:39:45.989359
# 1      0001b1d5-b74a-4cbf-aeb0-7df5947bf349 2019-10-09 18:33:55.577963
# 2      0001b1d5-b74a-4cbf-aeb0-7df5947bf349 2019-10-09 18:40:28.738785
# 3      0001b1d5-b74a-4cbf-aeb0-7df5947bf349 2019-10-21 19:52:30.778932
# 4      0001b1d5-b74a-4cbf-aeb0-7df5947bf349 2019-10-21 19:53:38.767230
# ...                                     ...                        ...
# 19554  fffb9e79-b927-4dbb-9b48-7fd09b23a62b 2019-11-03 14:32:55.956301
# 19555  fffb9e79-b927-4dbb-9b48-7fd09b23a62b 2019-11-03 14:33:47.921863
# 19556  fffb9e79-b927-4dbb-9b48-7fd09b23a62b 2019-11-03 15:36:01.007440
# 19557  fffb9e79-b927-4dbb-9b48-7fd09b23a62b 2019-11-03 15:48:05.420247
# 19558  fffb9e79-b927-4dbb-9b48-7fd09b23a62b 2019-11-03 16:07:40.932077
#
#        event_date  event_week     event_name  session_id  source
# ...

# %% [markdown]
# Проверка результата

# %%
data_filtred.duplicated(subset=['session_id','event_name']).sum()
# Out:
# 0

# %% [markdown]
# Дубликаты устранены

# %% [markdown]
# Для построения диаграммы нужно определить пары source-target, а также пронумеровать эти пары в соответствии с временем наступления события - это будет шаг между событиями.Для этого мы создадим функцию `add_features`

# %%
def add_features(df):

    """Функция генерации новых столбцов для исходной таблицы

   Args:
        data_filtred (pd.DataFrame): исходная таблица.
    Returns:
        pd.DataFrame: таблица с новыми признаками.
    """

    # сортируем по id и времени
    sorted_df = df.sort_values(by=['session_id', 'event_time']).copy()
    # добавляем шаги событий
    sorted_df['step'] = sorted_df.groupby('session_id').cumcount() + 1

    # добавляем узлы-источники и целевые узлы
    # узлы-источники - это сами события
    sorted_df['source'] = sorted_df['event_name']
    # добавляем целевые узлы
    sorted_df['target'] = sorted_df.groupby('session_id')['source'].shift(-1)

    # возврат таблицы без имени событий
    return sorted_df.drop(['event_name'], axis=1)

# преобразуем таблицу
data_filtred = add_features(data_filtred)
data_filtred.head(10)
# Out:
#                                 user_id                 event_time  \
# 0  0001b1d5-b74a-4cbf-aeb0-7df5947bf349 2019-10-07 13:39:45.989359
# 1  0001b1d5-b74a-4cbf-aeb0-7df5947bf349 2019-10-09 18:33:55.577963
# 2  0001b1d5-b74a-4cbf-aeb0-7df5947bf349 2019-10-09 18:40:28.738785
# 3  0001b1d5-b74a-4cbf-aeb0-7df5947bf349 2019-10-21 19:52:30.778932
# 4  0001b1d5-b74a-4cbf-aeb0-7df5947bf349 2019-10-21 19:53:38.767230
# 5  0001b1d5-b74a-4cbf-aeb0-7df5947bf349 2019-10-22 11:18:14.635436
# 6  0001b1d5-b74a-4cbf-aeb0-7df5947bf349 2019-10-22 11:19:10.529462
# 7  00157779-810c-4498-9e05-a1e9e3cedf93 2019-10-19 21:34:33.849769
# 8  00157779-810c-4498-9e05-a1e9e3cedf93 2019-10-19 21:40:38.990477
# 9  00157779-810c-4498-9e05-a1e9e3cedf93 2019-10-20 18:49:24.115634
#
#    event_date  event_week  session_id       source  step       target
# 0  2019-10-07          41           1    tips_show     1          NaN
# 1  2019-10-09          41           2          map     1    tips_show
# ...

# %% [markdown]
# В итоговой таблице:
#
# - события каждого id отсортированы по времени;
#
# - созданы пары событий source - target;
#
# - добавлен шаг между этими событиями для построения диаграммы;
#
# - удален столбец event_name, так как в дальнейших преобразованиях он использоваться не будет.

# %% [markdown]
# Следующее, что нужно сделать - это узнать количество шагов для нашей будущей диаграммы. Чем больше шагов, тем больше графических объектов в итоге будет отображено.Построим график с распределением уникальных событий (переходов) в разрезе сессий и узнаем максимальное количество шагов.

# %%
# Группировка данных по сессиям и подсчет уникальных событий
session_events = data_filtred.groupby('session_id')['source'].nunique().reset_index()

# %%
# строим график
fig = px.histogram(session_events,
                   x='source',
                   color_discrete_sequence=px.colors.qualitative.Pastel,
                   nbins=6)

# оформляем график
fig.update_layout(title='Распределение уникальных событий (переходов) в разрезе сессий',
                  xaxis=dict(range=[0, 6]),
                  title_x=0.45,
                  xaxis_title='Кол-во  уникальных событий в одной сессии',
                  yaxis_title='Кол-во сессий',
                  width=1000, # указываем размеры графика
                  height=600,
                  bargap=0.2,
                  yaxis_title_font=dict(size=16),
                  xaxis_title_font=dict(size=16),
                  title_font=dict(size=20))


fig.show() # выводим график

# %% [markdown]
# График с распределением событий (переходов) в разрезе сессий показывает, что максимальное количество шагов из уникальных событий в одной сессии = 6, это и будет являться максимальной длиной цепочки для построения нашей будущей диаграммы Санкея

# %% [markdown]
# **Создание индексов для source**
#
# Важным следующим шагом в подготовке данных является создание индексов для source. На каждом следующем шаге target становится source, и чтобы диаграмма коррректно генерировалась нужна правильная индексация source на каждом шаге.
#
# Создадим словарь, в котором ключи - это шаги, а значения - словари со списком названий source и соответствующих им индексов. Обратите внимание, что на следующем шаге индексы source продолжают нумерацию, а не начинают с 0, при том, что имена событий могут повторяться.
#
# Затем для каждого шага объединяем имена и индексы в еще один вложенный словарь. Все вложенные списки и словари потребуются в дальнейшем для генерации меток, подписей и размера каналов между source и target.

# %% [markdown]
# **Создание словаря с индексами source**

# %%
def get_source_index(df):

    """Функция генерации индексов source

    Args:
        df (pd.DataFrame): исходная таблица с признаками step, source, target.
    Returns:
        dict: словарь с индексами, именами и соответсвиями индексов именам source.
    """

    res_dict = {}

    count = 0
    # получаем индексы источников
    for no, step in enumerate(df['step'].unique().tolist()):
        # получаем уникальные наименования для шага
        res_dict[no+1] = {}
        res_dict[no+1]['sources'] = df[df['step'] == step]['source'].unique().tolist()
        res_dict[no+1]['sources_index'] = []
        for i in range(len(res_dict[no+1]['sources'])):
            res_dict[no+1]['sources_index'].append(count)
            count += 1

    # соединим списки
    for key in res_dict:
        res_dict[key]['sources_dict'] = {}
        for name, no in zip(res_dict[key]['sources'], res_dict[key]['sources_index']):
            res_dict[key]['sources_dict'][name] = no
    return res_dict


# создаем словарь
source_indexes = get_source_index(data_filtred)

# %% [markdown]
# **Генерация цветов для source**
#
# Для более наглядного представления можно разукрасить каждый source-target в разные цвета. Я рассмотрел 2 способа - случайная генерация и ручной выбор цветов.
#
# Цвета выберем в цветовой модели RGBA. Это необходимо, чтобы сделать каналы source-target более прозрачными, по отношению к блокам для лучшей читаемости схемы.
#
# Цвет будем генерировать для каждого уникального источника. Для этого создадим еще один словарь, в котором будут храниться соответствия source:color. По личному субъективному мнению, автоматически сгенерированные цвета не очень нравятся. Поэтому потратив немного времени выбрал те цвета, которые интереснее выглядят на белом фоне. Их можно загрузить, указав в функции colors_for_sources значение mode='custom' ('random' для случайной генерации цвета).

# %% [markdown]
# **Функция случайной генерации цветов**

# %%
def generate_random_color():

    """Случайная генерация цветов rgba

    Args:

    Returns:
        str: Строка со сгенерированными параметрами цвета
    """

    # сгенерим значение для каждого канала
    r, g, b = np.random.randint(255, size=3)
    return f'rgba({r}, {g}, {b}, 1)'

# %% [markdown]
# **Создание словаря с соответствиями source: color**

# %%
def colors_for_sources(mode):

    """Генерация цветов rgba

    Args:
        mode (str): сгенерировать случайные цвета, если 'random', а если 'custom' -
                    использовать заранее подготовленные
    Returns:
        dict: словарь с цветами, соответствующими каждому индексу
    """
    # словарь, в который сложим цвета в соответствии с индексом
    colors_dict = {}

    if mode == 'random':
        # генерим случайные цвета
        for label in data_filtred['source'].unique():
            r, g, b = np.random.randint(255, size=3)
            colors_dict[label] = f'rgba({r}, {g}, {b}, 1)'

    elif mode == 'custom':
        # присваиваем ранее подготовленные цвета
        colors = requests.get('https://raw.githubusercontent.com/rusantsovsv/senkey_tutorial/main/json/colors_senkey.json').json()
        for no, label in enumerate(data_filtred['source'].unique()):
            colors_dict[label] = colors['custom_colors'][no]

    return colors_dict



colors_dict = colors_for_sources(mode='custom')

# %% [markdown]
# **Создаем словарь с данными**
#
# Диаграмму будем отрисовывать с помощью Plotly. Для корректной (и более полной) отрисовки нужны следующие данные:
#
# sources - список с индексами source;
#
# targets - список с индексами target;
#
# values - количество уникальных пользователей, совершивших переход между узлами source-target ("объем" потока между узлами);
#
# labels - названия узлов;
#
# colors_labels - цвет узлов;
#
# link_color - цвет потоков между узлами;
#
# link_text - дополнительная информация.
#
# Следующие 2 функции помогут создать словарь этих списков:

# %% [markdown]
# **Расчет количества уникальных пользователей в процентах**

# %%
def percent_users(sources, targets, values):

    """
    Расчет уникальных id в процентах (для вывода в hover text каждого узла)

    Args:
        sources (list): список с индексами source.
        targets (list): список с индексами target.
        values (list): список с "объемами" потоков.

    Returns:
        list: список с "объемами" потоков в процентах
    """

    # объединим источники и метки и найдем пары
    zip_lists = list(zip(sources, targets, values))

    new_list = []

    # подготовим список словарь с общим объемом трафика в узлах
    unique_dict = {}

    # проходим по каждому узлу
    for source, target, value in zip_lists:
        if source not in unique_dict:
            # находим все источники и считаем общий трафик
            unique_dict[source] = 0
            for sr, tg, vl in zip_lists:
                if sr == source:
                    unique_dict[source] += vl

    # считаем проценты
    for source, target, value in zip_lists:
        new_list.append(round(100 * value / unique_dict[source], 1))

    return new_list

# %% [markdown]
# **Создание словаря с данными для отрисовки диаграммы**

# %%
def lists_for_plot(source_indexes=source_indexes, colors=colors_dict, frac=0):

    """
    Создаем необходимые для отрисовки диаграммы переменные списков и возвращаем
    их в виде словаря

    Args:
        source_indexes (dict): словарь с именами и индексами source.
        colors (dict): словарь с цветами source.
        frac (int): ограничение на минимальный "объем" между узлами.

    Returns:
        dict: словарь со списками, необходимыми для диаграммы.
    """

    sources = []
    targets = []
    values = []
    labels = []
    link_color = []
    link_text = []

    # проходим по каждому шагу
    for step in tqdm(sorted(data_filtred['step'].unique()), desc='Шаг'):
        if step + 1 not in source_indexes:
            continue

        # получаем индекс источника
        temp_dict_source = source_indexes[step]['sources_dict']

        # получаем индексы цели
        temp_dict_target = source_indexes[step+1]['sources_dict']

        # проходим по каждой возможной паре, считаем количество таких пар
        for source, index_source in tqdm(temp_dict_source.items()):
            for target, index_target in temp_dict_target.items():
                # делаем срез данных и считаем количество id
                temp_df = data_filtred[(data_filtred['step'] == step)&(data_filtred['source'] == source)&(data_filtred['target'] == target)]
                value = len(temp_df)
                # проверяем минимальный объем потока и добавляем нужные данные
                if value > frac:
                    sources.append(index_source)
                    targets.append(index_target)
                    values.append(value)
                    # делаем поток прозрачным для лучшего отображения
                    link_color.append(colors[source].replace(', 1)', ', 0.2)'))

    labels = []
    colors_labels = []
    for key in source_indexes:
        for name in source_indexes[key]['sources']:
            labels.append(name)
            colors_labels.append(colors[name])

    # посчитаем проценты всех потоков
    perc_values = percent_users(sources, targets, values)

    # добавим значения процентов для howertext
    link_text = []
    for perc in perc_values:
        link_text.append(f"{perc}%")

    # возвратим словарь с вложенными списками
    return {'sources': sources,
            'targets': targets,
            'values': values,
            'labels': labels,
            'colors_labels': colors_labels,
            'link_color': link_color,
            'link_text': link_text}


# создаем словарь
data_for_plot = lists_for_plot()
# Out:
# ...
# Шаг: 100%|██████████| 6/6 [00:03<00:00,  1.76it/s]

# %% [markdown]
# После подготовки данных приступим к созданию объекта диаграммы. Сохраним его в отдельную переменную senkey_diagram для дальнейшего сохранения или публикации:

# %% [markdown]
# **Создание объекта диаграммы**

# %%
def plot_senkey_diagram(data_dict=data_for_plot):

    """
    Функция для генерации объекта диаграммы Сенкей

    Args:
        data_dict (dict): словарь со списками данных для построения.

    Returns:
        plotly.graph_objs._figure.Figure: объект изображения.
    """

    fig = go.Figure(data=[go.Sankey(
        domain = dict(
          x =  [0,1],
          y =  [0,1]
        ),
        orientation = "h",
        valueformat = ".0f",
        node = dict(
          pad = 50,
          thickness = 15,
          line = dict(color = "black", width = 0.1),
          label = data_dict['labels'],
          color = data_dict['colors_labels']
        ),
        link = dict(
          source = data_dict['sources'],
          target = data_dict['targets'],
          value = data_dict['values'],
          label = data_dict['link_text'],
          color = data_dict['link_color']
      ))])
    fig.update_layout(title_text="Sankey Diagram", font_size=10, width=1000, height=600)

    # возвращаем объект диаграммы
    return fig


# сохраняем диаграмму в переменную
senkey_diagram = plot_senkey_diagram()

# %% [markdown]
# Отображение диаграммы Санкея

# %%
senkey_diagram.show()

# %% [markdown]
# На диаграмме Санкея толщина линии отвечает за кол-во сессий от одного  действия пользователя к другому. В рамках данного исследования мы найдём топ-4 сценария просмотра контактов пользователя.

# %% [markdown]
#  Самыми популярными сценариями стали:

# %% [markdown]
# -  tips_show - сontacts_show
# -  сontacts_show
# -  search_1 - сontacts_show
# -  map – tips_show – contacts_show

# %%
result = data_filtred.groupby('session_id')['source'].apply(tuple).reset_index()
result
# Out:
#        session_id                      source
# 0               1                (tips_show,)
# 1               2            (map, tips_show)
# 2               3            (tips_show, map)
# 3               4            (map, tips_show)
# 4               5     (search_1, photos_show)
# ...           ...                         ...
# 11888       11889            (contacts_show,)
# 11889       11890  (tips_show, contacts_show)
# 11890       11891  (tips_show, contacts_show)
# 11891       11892  (tips_show, contacts_show)
# 11892       11893                (tips_show,)
#
# [11893 rows x 2 columns]

# %%
pd.set_option('display.max_rows', None)
filtered_rows = result[result['source'].apply(lambda x: 'contacts_show' in x)]
filtered_rows['source'].value_counts(dropna=False)
# Out:
# source
# (tips_show, contacts_show)                                                           409
# (contacts_show,)                                                                     280
# (contacts_show, contacts_call)                                                       142
# (contacts_show, tips_show)                                                           103
# (map, tips_show, contacts_show)                                                       88
# (photos_show, contacts_show)                                                          84
# (search_1, contacts_show)                                                             59
# (search_1, contacts_show, contacts_call)                                              54
# (search_1, photos_show, contacts_show)                                                39
# (contacts_show, photos_show)                                                          39
# ...

# %%
pd.reset_option('display.max_rows')

# %% [markdown]
# ### Воронки действий пользователей  по топ 4 сценариям

# %% [markdown]
# По найденным сценариям нам необходимо построить воронки действий пользователей в целевое событие "contacts_show". Начнём строить воронки по убыванию популярности сценариев.

# %% [markdown]
# #### Топ 1 сценарий (tips_show -> contacts_show)

# %% [markdown]
# Найдём кол-во уникальных пользователей, которые совершили действие `tips_show` и из этих же пользователей далее совершили действие `contacts_show`.

# %%
#Фильтрация пользователей, совершивших действие "tips_show"
tips_show_users = data_filtred[data_filtred['source'] == 'tips_show']['user_id'].unique()

#Фильтрация пользователей, совершивших действие "contacts_show" из tips_show
contacts_show_users = data_filtred[(data_filtred['source'] == 'contacts_show') & (data_filtred['user_id'].isin(tips_show_users))]['user_id'].unique()

#списки пользователей, которые совершили каждое из указанных действий.
tips_show_users_count = len(tips_show_users)
contacts_show_users_count = len(contacts_show_users)

# %% [markdown]
# Создадим таблицу с воронкой событий и узнаем сколько пользователей добралось до contacts_show.

# %%
top_1_script = pd.DataFrame(
     [[tips_show_users_count],
      [contacts_show_users_count]], index=['tips_show','contacts_show'])

top_1_script.columns = ['count_user']
top_1_script
# Out:
#                count_user
# tips_show            2801
# contacts_show         516

# %% [markdown]
# Визуализируем полученный результат с помощью графика воронки событий. По результатам сделаем выводы.

# %%
fig = go.Figure(go.Funnel( x = top_1_script['count_user'],
                           y = [ 'tips_show',
                                'contacts_show'],
                           textposition = 'inside',
                           textinfo = "value+percent initial",
                           marker={'colorscale': 'plasma',
                                   'colorbar': {'bgcolor': None}}))
fig.update_layout(
    title='Воронка событий',
    title_x=0.55,
    template="simple_white",
    yaxis_title = 'Последовательность событий',
    yaxis_title_font=dict(size=18),
    title_font=dict(size=20))

fig.show()

# %% [markdown]
# С 2019-10-07 по 2019-11-03 по сценарию `tips_show -> contacts_show`:
#
# Увидело рекомендованные объявления 2801 пользователей, из них 516 посмотрело контакты продавца. Конверсия в целевое действие составила 18 %, это очень хороший показатель.

# %% [markdown]
# #### Топ 2 сценарий (contacts_show)

# %% [markdown]
# Найдём кол-во уникальных пользователей, которые совершили целевое действие `contacts_show` первым.

# %%
contacts_show_table = data_filtred.pivot_table(index=['user_id','session_id'],values='source',aggfunc='first').reset_index()
contacts_show_table = contacts_show_table.loc[contacts_show_table['source'] == 'contacts_show']

# %%
contacts_show_users_count = contacts_show_table['user_id'].nunique()

# %% [markdown]
# Создадим таблицу с воронкой событий и узнаем сколько пользователей добралось до contacts_show.

# %%
top_2_script = pd.DataFrame(
     [[contacts_show_users_count]], index=['contacts_show'])

top_2_script.columns = ['count_user']
top_2_script
# Out:
#                count_user
# contacts_show         421

# %% [markdown]
# Визуализируем полученный результат с помощью графика воронки событий. По результатам сделаем выводы.

# %%
fig = go.Figure(go.Funnel( x = top_2_script['count_user'],
                           y = ['contacts_show'],
                           textposition = 'inside',
                           textinfo = "value+percent initial",
                           marker={'colorscale': 'plasma',
                                   'colorbar': {'bgcolor': None}}))
fig.update_layout(
    title='Воронка событий',
    title_x=0.55,
    template="simple_white",
    yaxis_title = 'Последовательность событий',
    yaxis_title_font=dict(size=18),
    title_font=dict(size=20))

fig.show()

# %% [markdown]
# С 2019-10-07 по 2019-11-03 по сценарию `contacts_show`:
#
# Есть пользователи,у которых первым действием в приложении является просмотр контактов продавца. Это могло произойти,если пользователь перешел по ссылке сразу на контакты продавца. Численность таких пользователей составила 421ч.

# %% [markdown]
# #### Топ 3 сценарий (search_1 -> contacts_show)

# %% [markdown]
# Найдём кол-во уникальных пользователей, которые совершили действие `search_1` и из этих же пользователей далее совершили действие `contacts_show`.

# %%
#Фильтрация пользователей, совершивших действие "search_1"
search_1_users = data_filtred[data_filtred['source'] == 'search_1']['user_id'].unique()

#Фильтрация пользователей, совершивших действие "contacts_show" из search_1
contacts_show_users = data_filtred[(data_filtred['source'] == 'contacts_show') & (data_filtred['user_id'].isin(search_1_users))]['user_id'].unique()

#списки пользователей, которые совершили каждое из указанных действий.
search_1_users_count = len(search_1_users)
contacts_show_users_count = len(contacts_show_users)

# %% [markdown]
# Создадим таблицу с воронкой событий и узнаем сколько пользователей добралось до contacts_show.

# %%
top_3_script = pd.DataFrame(
     [[search_1_users_count],
      [contacts_show_users_count]], index=['search_1','contacts_show'])

top_3_script.columns = ['count_user']
top_3_script
# Out:
#                count_user
# search_1             1666
# contacts_show         377

# %% [markdown]
# Визуализируем полученный результат с помощью графика воронки событий. По результатам сделаем выводы.

# %%
fig = go.Figure(go.Funnel( x = top_3_script['count_user'],
                           y = [ 'search_1',
                                'contacts_show'],
                           textposition = 'inside',
                           textinfo = "value+percent initial",
                           marker={'colorscale': 'plasma',
                                   'colorbar': {'bgcolor': None}}))
fig.update_layout(
    title='Воронка событий',
    title_x=0.55,
    template="simple_white",
    yaxis_title = 'Последовательность событий',
    yaxis_title_font=dict(size=18),
    title_font=dict(size=20))

fig.show()

# %% [markdown]
# С 2019-10-07 по 2019-11-03 по сценарию `search_1 -> contacts_show`:
#
# Воспользовалось поиском в приложении 1666 пользователей, из них 377 посмотрело контакты продавца. Конверсия в целевое действие составила 23%,это очень хороший показатель.Хоть и численность пользователей совершивших целевое действие меньше, чем по сценарию tips_show -> contacts_show , но конверсия выше на 5%.

# %% [markdown]
# #### Топ 4 сценарий (map -> tips_show  ->  contacts_show)

# %% [markdown]
# Найдём кол-во уникальных пользователей, которые совершили действие `map` и из этих же пользователей далее совершили действие `tips_show` и из этих же пользователей далее совершили действие `сontacts_show`.

# %%
#Фильтрация пользователей, совершивших действие "map"
map_users = data[data['event_name'] == 'map']['user_id'].unique()

#Фильтрация пользователей, совершивших действие "tips_show" из map_users
tips_show_users = data[(data['event_name'] == 'tips_show') & (data['user_id'].isin(map_users))]['user_id'].unique()

#Фильтрация пользователей, совершивших целевое действие "contacts_show" из tips_show_users
contacts_show_users = data[(data['event_name'] == 'contacts_show') & (data['user_id'].isin(tips_show_users))]['user_id'].unique()

#списки пользователей, которые совершили каждое из указанных действий.
map_users_count = len(map_users)
tips_show_users_count = len(tips_show_users)
contacts_show_user_count = len(contacts_show_users)

# %% [markdown]
# Создадим таблицу с воронкой событий и узнаем сколько пользователей добралось до contacts_show.

# %%
top_4_script = pd.DataFrame(
     [[map_users_count],
      [tips_show_users_count],
      [contacts_show_user_count]], index=['map','tips_show','contacts_show'])

top_4_script.columns = ['count_user']
top_4_script
# Out:
#                count_user
# map                  1456
# tips_show            1352
# contacts_show         275

# %% [markdown]
# Визуализируем полученный результат с помощью графика воронки событий. По результатам сделаем выводы.

# %%
fig = go.Figure(go.Funnel( x = top_4_script['count_user'],
                           y = ['map',
                                'tips_show',
                                'contacts_show'],
                           textposition = 'inside',
                           marker={'colorscale': 'plasma',
                                   'colorbar': {'bgcolor': None}}))
fig.update_layout(
    title='Воронка событий',
    title_x=0.55,
    template="simple_white",
    yaxis_title = 'Последовательность событий',
    yaxis_title_font=dict(size=18),
    title_font=dict(size=20))

fig.show()

# %% [markdown]
# С 2019-10-07 по 2019-11-03 по сценарию `map -> tips_show -> contacts_show`:
#
# Открыло карту объявлений 1456 пользователей, из них 1352 пользователей увидело рекомендованные объявления из них 275 пользователей посмотрело контакты продавца. Конверсия из map -> contacts_show составила 8.9%, самая низкая среди всех рассмотреных.Это не удивительно, чем больше событий в сценарии, тем меньше пользователей доходит до целевого действия.

# %% [markdown]
# **Вывод**
#  По проведённому анализу влияния действий на совершение целевого события можно резюмировать следующее:
#
# 1. Самыми популярными сценариями в целевое действие стали:
#    -  tips_show - сontacts_show  (516ч. посмотрело контакты продавца. Конверсия в целевое действие составила 18 %)
#    -  сontacts_show (421ч. посмотрело контакты продавца первым действием. Это могло произойти,если пользователь перешел по ссылке сразу на контакты продавца)
#    -  search_1 - сontacts_show (377ч. посмотрело контакты продавца. Конверсия в целевое действие составила 23 %)
#    -  map – tips_show – contacts_show (275ч. посмотрело контакты продавца. Конверсия в целевое действие составила 8.9 %)
#
# 2. Больше всего пользователей приходит по сценарию  `tips_show - сontacts_show`
# 3. Весомая часть пользователей переходит на контакты продавца по ссылке объявления. Скорее всего знакомые делятся ссылкой с ними.
# 4. Самая высокая конверсия по сценарию `search_1 - сontacts_show`.Поисковые запросы хорошо отрабатывают запрос контаков продавца.
# 5. Чем больше событий в сценарии, тем меньше пользователей доходит до целевого действия, это подтверждает сценарий `map -> tips_show -> contacts_show`

# %% [markdown]
# ## Оценка частоты действий пользователей просмотревших контакты

# %% [markdown]
# В рамках дальнейшего исследования оценим,какие действия чаще совершают те пользователи, которые просматривают контакты и те, кто контакты не просматривает

# %% [markdown]
# ### Расчёт относительной частоты событий группы пользователей, которые смотрели контакты contacts_show

# %% [markdown]
# Найдём пользователей, которые смотрели контакты продавца. Создадим датафрейм с информацией по этим пользователям.

# %%
click_contacts_show = data.loc[data['event_name'] == 'contacts_show']['user_id'].unique()
table_click_contacts_show = data.loc[data['user_id'].isin(click_contacts_show)]

# %%
print(f'Общее кол-во уникальных пользователей,которые просматривают контакты продавца: {len(click_contacts_show)}')
# Out:
# Общее кол-во уникальных пользователей,которые просматривают контакты продавца: 981

# %% [markdown]
# Построим сводную таблицу с информацией по частоте действий пользователей просмотревших контакты

# %%
click_contacts_user = table_click_contacts_show.pivot_table(index='event_name',values='user_id',aggfunc={'user_id':'count'}).reset_index().sort_values(by='user_id',ascending=False)
click_contacts_user.columns=['event_name','count']
click_contacts_user['share%'] = round((click_contacts_user['count']/click_contacts_user['count'].sum())*100,2)
click_contacts_user
# Out:
#       event_name  count  share%
# 8      tips_show  12768   46.95
# 2  contacts_show   4529   16.65
# 5    photos_show   3828   14.08
# 6       search_1   2084    7.66
# 0    advert_open   1589    5.84
# 4            map   1101    4.05
# 1  contacts_call    541    1.99
# 3  favorites_add    424    1.56
# 7     tips_click    333    1.22

# %% [markdown]
# Построим график с распределением частоты действий пользователей

# %%
#Строим график
fig = px.bar(click_contacts_user,
             x='event_name',
             y='share%',
             hover_data=click_contacts_user.columns,
             color='event_name',
             color_discrete_sequence=px.colors.qualitative.Pastel)

# оформляем график
fig.update_layout(title='Распределение совершённых действий по пользователям',
                  title_x=0.45,
                  xaxis_title='Название действия',
                  yaxis_title='% совершённых действий',
                  width=1000, # указываем размеры графика
                  height=600,
                  yaxis_title_font=dict(size=16),
                  xaxis_title_font=dict(size=16),
                  title_font=dict(size=20))

fig.update_xaxes(tickangle=45)
fig.show() # выводим график

# %% [markdown]
# Более 45% всех действий пользователей приходится на `tips_show` при абсолютном значении в <12000 совершённых действий. Целевое действие `contacts_show` занимает 16.65% от всех совершаемых действий при абсолютном значении в 4529. Наименьшая доля приходится на `tips_click`, всего 1,22%. Это может говорить нам о том,что пользователей не интресуют рекомендованные объявления и конверсия в клики очень маленькая.Также по действию `favorites_add` можно заметить, что всего 1,5% всех действий пользователей приходится на добавление объявления в избранное.

# %% [markdown]
# ### Расчёт относительной частоты событий группы пользователей, которые не смотрели контакты contacts_show

# %% [markdown]
# Найдём пользователей, которые не смотрели контакты продавца. Создадим датафрейм с информацией по этим пользователям.

# %%
not_click_contacts_show = data.loc[(~data['user_id'].isin(click_contacts_show))]['user_id'].unique()
table_not_click_contacts_show = data.loc[(data['user_id'].isin(not_click_contacts_show))]

# %%
print(f'Общее кол-во уникальных пользователей,которые не смотрели контакты продавца: {len(not_click_contacts_show)}')
# Out:
# Общее кол-во уникальных пользователей,которые не смотрели контакты продавца: 3312

# %% [markdown]
# Построим сводную таблицу с информацией по частоте действий пользователей не смотревших контакты

# %%
not_click_contacts_user = table_not_click_contacts_show.pivot_table(index='event_name',values='user_id',aggfunc={'user_id':'count'}).reset_index().sort_values(by='user_id',ascending=False)
not_click_contacts_user.columns=['event_name','count']
not_click_contacts_user['share%'] = round((not_click_contacts_user['count']/not_click_contacts_user['count'].sum())*100,2)
not_click_contacts_user
# Out:
#       event_name  count  share%
# 6      tips_show  27287   58.06
# 3    photos_show   6184   13.16
# 4       search_1   4700   10.00
# 0    advert_open   4575    9.73
# 2            map   2780    5.91
# 1  favorites_add    993    2.11
# 5     tips_click    481    1.02

# %% [markdown]
# Построим график с распределением частоты действий пользователей

# %%
#Строим график
fig = px.bar(not_click_contacts_user,
             x='event_name',
             y='share%',
             hover_data=not_click_contacts_user.columns,
             color='event_name',
             color_discrete_sequence=px.colors.qualitative.Pastel)

# оформляем график
fig.update_layout(title='Распределение совершённых действий по пользователям',
                  title_x=0.45,
                  xaxis_title='Название действия',
                  yaxis_title='% совершённых действий',
                  width=1000, # указываем размеры графика
                  height=600,
                  yaxis_title_font=dict(size=16),
                  xaxis_title_font=dict(size=16),
                  title_font=dict(size=20))

fig.update_xaxes(tickangle=45)
fig.show() # выводим график

# %% [markdown]
# Почти 60% всех действий пользователей приходится на `tips_show` при абсолютном значении в <27000 совершённых действий. Целевое действие `contacts_show` отсутствует, как и `contacts_call`. Наименьшая доля совершённых действий всё так же приходится на `favorites_add`,`tips_click` при относительных значениях в 2.1% и 1% соответственно.

# %% [markdown]
# Мы построили графики распределения частоты действий пользователей которые просматривают контакты и те, кто контакты не просматривает.Теперь объединим графики в один для сравнения относительных значений действий двух групп. Предварительно добавим в каждый из датафреймов `click_contacts_user` и `not_click_contacts_user`  столбец `group` с информацией по совершению целевого действия для разделения групп. Объединим  полученные датафреймы в один.

# %%
# Объединяем данные с новой переменной 'group', чтобы разделить категории
click_contacts_user['group'] = 'click'
not_click_contacts_user['group'] = 'not_click'

# Объединяем данные из двух наборов
combined_data = pd.concat([click_contacts_user, not_click_contacts_user])

# %% [markdown]
# Построим столбчатую диаграмму с распределением совершённых действий в разрезе пользователей просмотревших контакты(`click`) и тех, кто контакты не смотрел(`not_click`).Отобразим два распределения на одном графике и сравним их.

# %%
#Строим график
fig = px.bar(combined_data,
             x='event_name',
             y='share%',
             color='group',
             barmode='group',# Устанавливаем режим группировки
             hover_data=combined_data.columns,
             color_discrete_sequence=px.colors.qualitative.Pastel)

# Оформляем график
fig.update_layout(title='Распределение совершённых действий по пользователям',
                  title_x=0.45,
                  xaxis_title='Название действия',
                  yaxis_title='% совершённых действий',
                  width=1000,
                  height=600,
                  yaxis_title_font=dict(size=16),
                  xaxis_title_font=dict(size=16),
                  title_font=dict(size=20))

fig.update_xaxes(tickangle=45)

# Отображаем график
fig.show()

# %% [markdown]
# Группе пользователей, которая смотрела контакты  на ~12% реже приходят уведомления с рекомендованными объявлениями, чем группе с не смотревшими контакты пользователями.Возможно, это связано с алгоритмами приложения, пользователи не совершавшие целевое действие стимулируются через показы рекомендованных объявлений. Просматривают фотографии в объявлении чаще пользователи, которые смотрели контакты,разница составляет ~1%. Действия пользователей связанных с поиском объявлений,открытием объявления и карты объявлений чаще у группы с не смотревшими контакты продавца. Видно, что потребность в нужном им товаре или услуге не удовлетворена и они ищут необходимое объявление активнее.

# %% [markdown]
# **Вывод**
# По результатам оценки частоты действий группы пользователей просмотревших контакты и группы не просмотревших контакты можно сказать следующее:
# - **Пользователи которые смотрели контакты contacts_show**:
#   - Более 45% всех действий пользователей приходится на tips_show при абсолютном значении в <12000 совершённых действий.
#   - Целевое действие contacts_show занимает 16.65% от всех совершаемых действий при абсолютном значении в 4529.
#   - Наименьшая доля приходится на tips_click, всего 1,22%. Это может говорить нам о том,что пользователей не интресуют рекомендованные объявления и конверсия в клики очень маленькая.
#   - По действию favorites_add можно заметить, что всего 1,5% всех действий пользователей приходится на добавление объявления в избранное.
#
# - **Пользователи которые не смотрели контакты contacts_show**:
#   - Почти 60% всех действий пользователей приходится на tips_show при абсолютном значении в <27000 совершённых действий.         - Наименьшая доля совершённых действий всё так же приходится на favorites_add,tips_click при относительных значениях в 2.1% и 1% соответственно.
#
# - **По общему графику сравнения относительных значений совершённых действий двух групп.**
#   - Группе пользователей, которая смотрела контакты на ~12% реже приходят уведомления с рекомендованными объявлениями, чем группе с не смотревшими контакты пользователями.Возможно, это связано с алгоритмами приложения, пользователи не совершавшие целевое действие стимулируются через показы рекомендованных объявлений.
#   - Просматривают фотографии в объявлении чаще пользователи, которые смотрели контакты,разница составляет ~1%.
#   - Действия пользователей связанных с поиском объявлений,открытием объявления и карты объявлений чаще у группы с не смотревшими контакты продавца. Видно, что потребность в нужном им товаре или услуге не удовлетворена и они ищут необходимое объявление активнее.

# %% [markdown]
# ## Проверка гипотез

# %% [markdown]
# Продакт-менеджеры приложения хотят увеличить вовлеченность текущих и привлечение новых пользователей. Для этого нам необходимо проверить несколько гипотез, котрые помогут проработать дальнейшие мероприятия для улучшения приложения с точки зрения пользовательского опыта.
#
# В рамках анализа проверим гипотезы:
#
# 1. Проверка гипотезы о различии конверсии в просмотры контактов пользователей совершивших действия tips_show и tips_click и пользователей совершивших только действие tips_show.
#
# 2. Проверка гипотезы о различии конверсии в просмотры контактов пользователей привлечённых из рекламного источника "yandex" и пользователей привлечённых из рекламного источника "google".

# %% [markdown]
# ### Проверка гипотезы о различии конверсии в просмотры контактов пользователей совершивших действия tips_show и tips_click и пользователей совершивших только действие tips_show

# %% [markdown]
# Для проверки гипотезы нам необходимо разделить пользователей на две группы:
#
# - Группа А - пользователи совершившие действия tips_show и tips_click -> contacts_show
# - Группа B - пользователи совершившие действия tips_show (без tips_click) -> contacts_show

# %% [markdown]
# **Группа А** tips_show и tips_click -> contacts_show

# %% [markdown]
# Создадим группу А с уникальным кол-ом пользователей дошедших до целевого действия среди пользователей совершивших действия tips_show и tips_click

# %%
tips_show_users_A = data[data['event_name'] == 'tips_show']['user_id'].unique()

tips_click_users_A = data[(data['event_name'] == 'tips_click') & (data['user_id'].isin(tips_show_users_A))]['user_id'].unique()

contacts_show_users_A = data[(data['event_name'] == 'contacts_show') & (data['user_id'].isin(tips_click_users_A))]['user_id'].unique()


#списки пользователей, которые совершили каждое из указанных действий.
tips_show_users_count_A = len(tips_show_users_A)
tips_click_users_count_A = len(tips_click_users_A)
contacts_show_users_count_A = len(contacts_show_users_A)

# %%
group_A = pd.DataFrame(
     [[tips_show_users_count_A],
      [tips_click_users_count_A],
      [contacts_show_users_count_A]],
       index=['tips_show','tips_click','contacts_show'])

group_A.columns = ['count_user']
group_A
# Out:
#                count_user
# tips_show            2801
# tips_click            297
# contacts_show          91

# %% [markdown]
# Информация о количестве уникальных пользователей на каждом шаге по группе А - получена.

# %% [markdown]
# **Группа В** tips_show -> contacts_show

# %% [markdown]
# Создадим группу B с уникальным кол-ом пользователей совершивших целевое действие по  сценарию tips_show (без tips_click) -> contacts_show на каждом шаге.

# %%
tips_show_users_B = data[(data['event_name'] == 'tips_show' ) & (~data['user_id'].isin(tips_click_users_A))]['user_id'].unique()

contacts_show_users_B = data[(data['event_name'] == 'contacts_show') & (data['user_id'].isin(tips_show_users_B))]['user_id'].unique()

#списки пользователей, которые совершили каждое из указанных действий.
tips_show_users_count_B = len(tips_show_users_B)
contacts_show_user_count_B = len(contacts_show_users_B)

# %%
group_B = pd.DataFrame(
     [[tips_show_users_count_B],
     [contacts_show_user_count_B]], index=['tips_show','contacts_show'])

group_B.columns = ['count_user']
group_B
# Out:
#                count_user
# tips_show            2504
# contacts_show         425

# %% [markdown]
# Информация о количестве уникальных пользователей на каждом шаге по группе B - получена.

# %% [markdown]
# Важно понять, отличается ли конверсия в просмотры контактов пользователей совершивших действия tips_show и tips_click и пользователей совершивших только действие tips_show (без tips_click) . Результат проверки данной гипотезы поможет менеджерам проработать дальнейшие мероприятия для улучшения приложения.

# %% [markdown]
# Осуществлять проверку на возможную стат. значимость различий между группами А и B мы будем с помощью проверки гипотезы о равенстве долей(z тест). Мы будем сравнивать пропорции(конверсию в contacts_show) двух групп. Сами группы будут разделены на А и Б.Разница между пропорциями, наблюдаемыми в группах, будет нашей статистикой. Всего будет проведён 1 тест, сравнение пропорциий tips_click -> contacts_show группы А и tips_show -> contacts_show группы B.

# %% [markdown]
# Для проведения теста сформулируем гипотезы:
#
# - Н0 : конверсии групп  равны
# - Н1 : конверсии групп  неравны

# %% [markdown]
# Воспользуемся готовым тестом `proportions_ztest` для проверки гипотезы. Проверим, будет ли отличие между группами А и B статистически значимым. Зададим пороговый уровень статистической значимости alpha = 0.05 (5% вероятности), что результат получен случайно и не соответствует действительности,вероятность ошибки первого рода.

# %%
alpha = 0.05 # задаём уровень статистической значимости в 5%

contacts_show = [group_A.loc['contacts_show','count_user'], group_B.loc['contacts_show','count_user']]
tips_show = [group_A.loc['tips_click','count_user'], group_B.loc['tips_show','count_user']]
results = proportions_ztest(contacts_show, tips_show)[1]
print('p-значение:{0:.3f}'.format(results))

if results < alpha:
    print('Отвергаем нулевую гипотезу, конверсии групп неравны')
else:
    print('Не получилось отвергнуть нулевую гипотезу,конверсии групп равны')
# Out:
# p-значение:0.000
# Отвергаем нулевую гипотезу, конверсии групп неравны

# %% [markdown]
# Найдём относительное различие в конверсии между группами А и B в %.

# %%
print("Относительное различие в конверсии  группы B к A составило: {0:.3f}%".format((abs((group_B.loc['contacts_show','count_user'] / group_B.loc['tips_show','count_user'])/(group_A.loc['contacts_show','count_user']/group_A.loc['tips_click','count_user']) - 1)*100)))
# Out:
# Относительное различие в конверсии  группы B к A составило: 44.605%

# %% [markdown]
# - По результатам статистического теста мы можем сделать вывод, что **конверсии в просмотры контактов пользователей совершивших действия tips_show и tips_click и пользователей совершивших только действие tips_show (без tips_click) отличаются, так как p-value = 0.000(0%), что меньше уровня статистической значимости в 5%. Соответсвенно есть причины отвергнуть нулевую гипотезу, конверсии групп неравны**
# - Расчёты относительного изменения, подтверждают результат теста. Видно существенное различие конверсии  группы B к A в 44%

# %% [markdown]
# ### Проверка гипотезы о различии конверсии в просмотры контактов пользователей привлечённых из рекламного источника "yandex" и пользователей привлечённых из рекламного источника "google".

# %% [markdown]
# Для проверки гипотезы нам необходимо разделить пользователей на две группы:
#
# - Группа А - пользователи привлечённые из рекламного источника "yandex"
# - Группа B - пользователи привлечённые из рекламного источника "google"

# %% [markdown]
# **Группа А**

# %% [markdown]
# Создадим группу А с уникальным кол-ом пользователей привлечённых из рекламного источника "yandex"  и  кол-ом этих пользователей совершивших целевое действие

# %%
yandex_users = data[data['source'] == 'yandex']['user_id'].unique()

contacts_show_users_A = data[(data['event_name'] == 'contacts_show') & (data['user_id'].isin(yandex_users))]['user_id'].unique()


#списки пользователей, которые совершили каждое из указанных действий.
yandex_users_count = len(yandex_users)
contacts_show_users_count_A = len(contacts_show_users_A)

# %%
group_A = pd.DataFrame(
     [[yandex_users_count],
      [contacts_show_users_count_A]],
       index=['yandex_users','contacts_show'])

group_A.columns = ['count_user']
group_A
# Out:
#                count_user
# yandex_users         1934
# contacts_show         478

# %% [markdown]
# Информация о количестве уникальных пользователей по источнику yandex  получена.

# %% [markdown]
# **Группа B**

# %% [markdown]
# Создадим группу B с уникальным кол-ом пользователей привлечённых из рекламного источника "google"  и  кол-ом этих пользователей совершивших целевое действие

# %%
google_users = data[data['source'] == 'google']['user_id'].unique()

contacts_show_users_B = data[(data['event_name'] == 'contacts_show') & (data['user_id'].isin(google_users))]['user_id'].unique()


#списки пользователей, которые совершили каждое из указанных действий.
google_users_count = len(google_users)
contacts_show_users_count_B = len(contacts_show_users_B)

# %%
group_B = pd.DataFrame(
     [[google_users_count],
      [contacts_show_users_count_B]],
       index=['google_users','contacts_show'])

group_B.columns = ['count_user']
group_B
# Out:
#                count_user
# google_users         1129
# contacts_show         275

# %% [markdown]
# Информация о количестве уникальных пользователей по источнику google  получена.

# %% [markdown]
# Проверим, что попавший в одну из групп пользователь остаётся в этой группе до конца теста. Если одному и тому же пользователю присвоен разный рекламный источник,то результаты такого теста нельзя интерпретировать однозначно.

# %%
# проверка на пересечение пользователей между группами
google_users_set = set(google_users)
yandex_users_set = set(yandex_users)

print(f'Пересечение пользователей между группами А и В: {len(google_users_set.intersection(yandex_users_set))}')
# Out:
# Пересечение пользователей между группами А и В: 0

# %% [markdown]
# Теперь мы удостоверились, что пересекающихся пользователей между группами А и B нет
# Можно проводить дальнейший анализ

# %% [markdown]
# Важно понять, отличается ли конверсия в просмотры контактов пользователей пользователей привлечённых из рекламного источника "yandex" и пользователей привлечённых из рекламного источника "google". Результат проверки данной гипотезы поможет маркетологам проработать дальнейшие мероприятия для выбора наилучшего рекламного источника для привлечения новых пользователей.

# %% [markdown]
# Осуществлять проверку на возможную стат. значимость различий между группами А и B мы будем с помощью проверки гипотезы о равенстве долей(z тест). Мы будем сравнивать пропорции(конверсию в contacts_show) двух групп. Сами группы будут разделены на А и Б.Разница между пропорциями, наблюдаемыми в группах, будет нашей статистикой. Всего будет проведён 1 тест, сравнение пропорциий yandex_users -> contacts_show  с google_users -> contacts_show

# %% [markdown]
# Для проведения теста сформулируем гипотезы:
#
# - Н0 : конверсии групп  равны
# - Н1 : конверсии групп  неравны

# %% [markdown]
# Воспользуемся готовым тестом `proportions_ztest` для проверки гипотезы. Проверим, будет ли отличие между группами А и B статистически значимым. Зададим пороговый уровень статистической значимости alpha = 0.05 (5% вероятности), что результат получен случайно и не соответствует действительности,вероятность ошибки первого рода.

# %%
alpha = 0.05 # задаём уровень статистической значимости в 5%

contacts_show = [group_A.loc['contacts_show','count_user'], group_B.loc['contacts_show','count_user']]
source_user = [group_A.loc['yandex_users','count_user'], group_B.loc['google_users','count_user']]
results = proportions_ztest(contacts_show, source_user)[1]
print('p-значение:{0:.3f}'.format(results))

if results < alpha:
    print('Отвергаем нулевую гипотезу, конверсии групп неравны')
else:
    print('Не получилось отвергнуть нулевую гипотезу,конверсии групп равны')
# Out:
# p-значение:0.824
# Не получилось отвергнуть нулевую гипотезу,конверсии групп равны

# %% [markdown]
# Найдём относительное различие в конверсии между группами А и B в %.

# %%
print("Относительное различие в конверсии  группы А к B составило: {0:.3f}%".format((abs((group_A.loc['contacts_show','count_user'] / group_A.loc['yandex_users','count_user'])/(group_B.loc['contacts_show','count_user']/group_B.loc['google_users','count_user']) - 1)*100)))
# Out:
# Относительное различие в конверсии  группы А к B составило: 1.469%

# %% [markdown]
# - По результатам статистического теста мы можем сделать вывод, что **конверсии в просмотры контактов пользователей привлечённых из рекламного источника "yandex" и пользователей привлечённых из рекламного источника "google" равны, так как p-value = 0.824(82.4%), что больше уровня статистической значимости в 5%. Соответсвенно нет причин отвергнуть нулевую гипотезу, конверсии групп равны**
# - Расчёты относительного изменения, подтверждают результат теста. Видно несущественное различие конверсии  группы А к B в 1.469%

# %% [markdown]
# **Вывод**
# Нами были проведены A/B тесты,чтобы подтвердить или опровергнуть гипотезу о существовании либо отсутствии различий конверсии в целевое действие в группах. А конкретно, нас интересовало, как влияет сценарий и источник привлечения пользователя на целевое действие.Для проведения тестов мы воспользовались стат. критерием о  проверке гипотезы о равенстве долей(z тест).
#
#
# Мы провели 2 стат. теста и проверили 2 гипотезы.
#    - Гипотеза `о различии конверсии в просмотры контактов пользователей совершивших действия tips_show и tips_click и пользователей совершивших только действие tips_show (без tips_click)` была доказана, так как результат работы теста: p-value = 0.000(0%), что меньше уровня статистической значимости в 5%. Конверсии групп неравны. Расчёты относительного изменения, подтверждают результат теста. Видно существенное различие конверсии группы B к A в 44%
#
#    - Гипотеза `о различии конверсии в просмотры контактов пользователей привлечённых из рекламного источника "yandex" и пользователей привлечённых из рекламного источника "google"` была опровергнута, так как результат работы теста: p-value = 0.824(82.4%), что больше уровня статистической значимости в 5%. Конверсии групп равны. Расчёты относительного изменения, подтверждают результат теста. Видно несущественное различие конверсии группы А к B в 1.469%

# %% [markdown]
# ## Общий вывод

# %% [markdown]
# В рамках проекта был проведён исследовательский анализ приложения,проанализировано влияние действий пользователей на совершение целевого события и построены воронки по популярным сценариям. Осуществлено А/В тестирование по выдвинутым гипотезам.
#
# **В процессе обзора и предобработки данных было обнаружено:**
#
# - Наименования столбцов приведены к нижнему,змеиному регистру. Порядок расположения столбцов выстроен логично.
# - Таблицы объединены в один датафрейм.
# - Пропуски не выявлены.
# - Явные дубликаты не выявлены.
# - Столбец `event_time` приведён к формату даты и времени.
# - Категории действий пользователей укрупнены.
# - Неявные дубликаты не выявлены.
# - Добавлены:
#   - столбец session_id с информацией по сессиям пользователей
#   - столбец event_date с информацией по дате совершения действия пользователем
#   - столбец event_week с информацией по номеру недели совершения действия пользователем
#
# **В рамках исследования данных были обнаружены некоторые зависимости и особенности:**
#
# 1. Анализируемый период составил 27 дней    С `2019-10-07 00:00:00` по `2019-11-03 23:58:12`
# 2. Общее количество совершённых действий пользователями 74197
# 3. Общее количество сессий пользователей 11893
# 4. Число уникальных пользователей за весь период составило 4293
# 5. Пик пользователей приходится от 4 до 6 действий на человека. Количество действий на пользователя:
#    - Cреднее количество действий на одного пользователя 17
#    - Медианное количество действий на одного пользователя 9
#    - Минимальное количество действий на одного пользователя 1
#    - Максимальное количество действий на одного пользователя 478
# 6. Пик пользователей приходится на 1 сессию. Основная часть пользователей совершила не более 5 сессий за 27 дней использования приложения. Количество сессий на пользователя:
#    - Cреднее количество сессий на одного пользователя 3
#    - Медианное количество сессий на одного пользователя 2
#    - Минимальное количество сессий на одного пользователя 1
#    - Максимальное количество сессий на одного пользователя 119
# 7. Пользователи из источника привлечения "yandex" имеют самое большое медианное значение длительности сессии на пользователя, длительность составила 4.68 мин. На втором месте "google" с длительностью 4.09 мин. Пользователи перешедшие с источника привлечения "other" меньше всего проводят времени за одну сессию, всего ~ 3 мин.
# 8. Среднее количество уникальных пользователей в день 279. Среднее количество уникальных пользователей в неделю 1382. По последней неделе (с 27 октября 2019 г. по 3 ноября 2019г. наблюдается тренд на снижение пользовательской активности, абсолютное значение составляет 1416 пользователей. Однако график DAU отражает общий тренд на увеличение пользовательской активности.
# 9. Доля пользователей из канала привлечения "yandex" наибольшая среди всех. Доля составляет 45.1%, при абсолютном значении в 1934ч. Доли источников "other" и "google" составляют 28.7% и 26.3% соответственно.
# 10. Более 50% всех действий пользователей приходится на tips_show при абсолютном значении в <40000 совершённых действий. Целевое действие contacts_show занимает 6.1% от всех совершаемых действий при абсолютном значении в 4529. Наименьшая доля приходится на contacts_call, менее 1%. Это может говорить нам о том,что пользователи не звонят напрямую из нашего приложения, а копируют телефонный номер.
# 11. В каждой шестой сессии пользователь просматривает контакты в объявлении.Процентная величина составила 16%, при абсолютном значении в 1900 сессий.
#
#
# **Анализ влияния действий на совершение целевого события**
#
# 1. Самыми популярными сценариями в целевое действие стали:
#    -  tips_show - сontacts_show  (516ч. посмотрело контакты продавца. Конверсия в целевое действие составила 18 %)
#    -  сontacts_show (421ч. посмотрело контакты продавца первым действием. Это могло произойти,если пользователь перешел по ссылке сразу на контакты продавца)
#    -  search_1 - сontacts_show (377ч. посмотрело контакты продавца. Конверсия в целевое действие составила 23 %)
#    -  map – tips_show – contacts_show (275ч. посмотрело контакты продавца. Конверсия в целевое действие составила 8.9 %)
#
# 2. Больше всего пользователей приходит по сценарию  `tips_show - сontacts_show`
# 3. Весомая часть пользователей переходит на контакты продавца по ссылке объявления. Скорее всего знакомые делятся ссылкой с ними.
# 4. Самая высокая конверсия по сценарию `search_1 - сontacts_show`.Поисковые запросы хорошо отрабатывают запрос контаков продавца.
# 5. Чем больше событий в сценарии, тем меньше пользователей доходит до целевого действия, это подтверждает сценарий `map -> tips_show -> contacts_show`
#
#
# **Оценка частоты действий пользователей просмотревших контакты**
#
# - `Пользователи которые смотрели контакты contacts_show`:
#   - Более 45% всех действий пользователей приходится на tips_show при абсолютном значении в <12000 совершённых действий.
#   - Целевое действие contacts_show занимает 16.65% от всех совершаемых действий при абсолютном значении в 4529.
#   - Наименьшая доля приходится на tips_click, всего 1,22%. Это может говорить нам о том,что пользователей не интресуют рекомендованные объявления и конверсия в клики очень маленькая.
#   - По действию favorites_add можно заметить, что всего 1,5% всех действий пользователей приходится на добавление объявления в избранное.
#
# - `Пользователи которые не смотрели контакты contacts_show`:
#   - Почти 60% всех действий пользователей приходится на tips_show при абсолютном значении в <27000 совершённых действий.         - Наименьшая доля совершённых действий всё так же приходится на favorites_add,tips_click при относительных значениях в 2.1% и 1% соответственно.
#
# - `По общему графику сравнения относительных значений совершённых действий двух групп:`
#   - Группе пользователей, которая смотрела контакты на ~12% реже приходят уведомления с рекомендованными объявлениями, чем группе с не смотревшими контакты пользователями.Возможно, это связано с алгоритмами приложения, пользователи не совершавшие целевое действие стимулируются через показы рекомендованных объявлений.
#   - Просматривают фотографии в объявлении чаще пользователи, которые смотрели контакты,разница составляет ~1%.
#   - Действия пользователей связанных с поиском объявлений,открытием объявления и карты объявлений чаще у группы с не смотревшими контакты продавца. Видно, что потребность в нужном им товаре или услуге не удовлетворена и они ищут необходимое объявление активнее.
#
#
#
#
# **Проверка гипотез**
#
# Нами были проведены A/B тесты,чтобы подтвердить или опровергнуть гипотезу о существовании либо отсутствии различий конверсии в целевое действие в группах. А конкретно, нас интересовало, как влияет сценарий и источник привлечения пользователя на целевое действие.Для проведения тестов мы воспользовались стат. критерием о  проверке гипотезы о равенстве долей(z тест).
#
#
# Мы провели 2 стат. теста и проверили 2 гипотезы.
#    - Гипотеза `о различии конверсии в просмотры контактов пользователей совершивших действия tips_show и tips_click и пользователей совершивших только действие tips_show (без tips_click)` была доказана, так как результат работы теста: p-value = 0.000(0%), что меньше уровня статистической значимости в 5%. Конверсии групп неравны. Расчёты относительного изменения, подтверждают результат теста. Видно существенное различие конверсии группы B к A в 44%
#
#    - Гипотеза `о различии конверсии в просмотры контактов пользователей привлечённых из рекламного источника "yandex" и пользователей привлечённых из рекламного источника "google"` была опровергнута, так как результат работы теста: p-value = 0.824(82.4%), что больше уровня статистической значимости в 5%. Конверсии групп равны. Расчёты относительного изменения, подтверждают результат теста. Видно несущественное различие конверсии группы А к B в 1.469%
#
# **Рекомендации**
# - Отделу маркетинга стоило бы заняться поиском альтернативных рекламных источников привлечения пользователей с последующей проверкой конверсии в целевое действие пользователей по новым источникам. Необходимо внимательно рассмотреть ЦА привлекаемых пользователей. Следует ориентироваться на сегмент пользователей с низким, ниже среднего и средним доходом.
# - Добавить push уведомления с информацией  исходя из модели поведения пользователя на сайте и его поисковых запросов. Тем самым мы смогли бы повысить DAU,WAU,MAU метрики.
# - Доработать алгоритмы рекомендации объявления. Пользователи очень редко кликают по рекомендованным объявлениям,всего 1,1% всех действий приходится на это событие.Это говорит нам о том, что система рекомендаций настроена неточно.
# - На период раскрутки приложения и набора пользователей есть необходимость в предоставлении доступа к бесплатному размещению объявлений в неограниченном кол-ве.

# %% [markdown]
# ## Презентация и дашборд

# %% [markdown]
# В рамках проекта мы подготовили презентацию и дашборд проведённого анализа поведения пользователей мобильного приложения «Ненужные вещи». Наше исследование поведения пользователей подскажет заказчику как улучшить приложение с точки зрения пользовательского опыта.

# %% [markdown]
# [Дашборд](https://public.tableau.com/views/DashboardofthemobileapplicationUnnecessarythings/sheet2?:language=en-US&publish=yes&:display_count=n&:origin=viz_share_link)

# %% [markdown]
# [Презентация](https://disk.yandex.ru/i/yFFbG6nfLJYzIA)
